# %% [markdown]
# ## Web Scraping with `Requests` and `BeautifulSoup`

# %% [markdown]
# #### 1. Import `requests` and `BeautifulSoup` and read an url of your choice:

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.pokemon.com/us/')

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# - html:

# %%
response.content
# Out:
# b'\n\n\n\n\n\n<!DOCTYPE html>\n<html class="no-js " lang="en">\n<head>\n  <meta charset="utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQ4OWFZXGwIAXFZTBgI=",licenseKey:"ba34eb72cb",applicationID:"1087113"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(27),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{l?l-=1:o(c||new UncaughtException(t,e,n),!0)}catch(u){try{i("ierr",[u,s.now(),!0])}catch(d){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(28),c=t("ee"),s=t("loader"),u=t("gos"),f=window.onerror,d=!1,p="nr@seenError",l=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(l+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(u(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,T=g.hash,this[f]=y.now()}function o(){L--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[f],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",u="-body",f="fn"+c,d="fn"+s,p="cb"+c,l="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),P=t(14),M=t(9),S=t("ee"),C=S.get("tracer");t(16),y.features.spa=!0;var T,L=0;S.on(f,r),b.on(p,r),M.on(p,r),S.on(d,o),b.on(l,o),M.on(l,o),S.buffer([f,d,"xhr-done","xhr-resolved"]),R.buffer([f]),O.buffer(["setTimeout"+s,"clearTimeout"+c,f]),P.buffer([f,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+u+c,m+u+s]),E.buffer(["newURL"]),x.buffer([f]),b.buffer(["propagate",p,l,"executor-err","resolve"+c]),C.buffer([f,"no-"+f]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+c),a(S,"xhr-resolved"),a(S,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",u="addEventListener",f="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),this.bstType])}),c.o ...

# %% [markdown]
# - This is not easy to understand; let's get a more readable version with BeautifulSoup instead:

# %%
def makesoup(response):
    return BeautifulSoup(response.content, 'html5lib')

makesoup(response)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en"><head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQ4OWFZXGwIAXFZTBgI=",licenseKey:"ba34eb72cb",applicationID:"1087113"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(27),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{l?l-=1:o(c||new UncaughtException(t,e,n),!0)}catch(u){try{i("ierr",[u,s.now(),!0])}catch(d){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(28),c=t("ee"),s=t("loader"),u=t("gos"),f=window.onerror,d=!1,p="nr@seenError",l=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(l+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(u(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,T=g.hash,this[f]=y.now()}function o(){L--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[f],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",u="-body",f="fn"+c,d="fn"+s,p="cb"+c,l="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),P=t(14),M=t(9),S=t("ee"),C=S.get("tracer");t(16),y.features.spa=!0;var T,L=0;S.on(f,r),b.on(p,r),M.on(p,r),S.on(d,o),b.on(l,o),M.on(l,o),S.buffer([f,d,"xhr-done","xhr-resolved"]),R.buffer([f]),O.buffer(["setTimeout"+s,"clearTimeout"+c,f]),P.buffer([f,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+u+c,m+u+s]),E.buffer(["newURL"]),x.buffer([f]),b.buffer(["propagate",p,l,"executor-err","resolve"+c]),C.buffer([f,"no-"+f]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+c),a(S,"xhr-resolved"),a(S,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",u="addEventListener",f="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),"requestAnim ...
#   <meta content="en" http-equiv="Content-Language"/>
#   <meta content="en" name="language"/>
#   <link href="https://assets.pokemon.com/static2/_ui/img/favicon.ico" rel="shortcut icon"/>
#
#   <title>The Official Pokémon Website | Pokemon.com |
#
#     Explore the World of Pokémon
#
# </title>
#
#
#
#
#   <meta content="The official source for Pokémon news and information on the Pokémon Trading Card Game, apps, video games, animation, and the Pokédex." name="description"/>
#
#
#
#
#
#
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#
#   <link href="https://assets.pokemon.com/static2/_ui/css/main.css" rel="stylesheet"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto:400,700" rel="stylesheet" type="text/css"/>
#
#
#
#   <link href="https://www.pokemon.com/fr/" hreflang="fr" rel="alternate"/>
#   <link href="https://www.pokemon.com/us/" hreflang="en" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-do" rel="alternate"/>
#   <link href="https://www.pokemon.com/de/" hreflang="de" rel="alternate"/>
#   <link href="https://www.pokemon.com/it/" hreflang="it" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-py" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-cl" rel="alternate"/>
#   <link href="https://www.pokemon.com/br/" hreflang="pt-br" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-gt" rel="alternate"/>
#   <link href="https://www.pokemon.com/fi/" hreflang="fi" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-mx" rel="alternate"/>
#   <link href="https://www.pokemon.com/jp/" hreflang="ja" rel="alternate"/>
#   <link href="https://www.pokemon.com/es/" hreflang="es" rel="alternate"/>
#   <link href="https://www.pokemon.com/uk/" hreflang="en-gb" rel="alternate"/>
#   <link href="https://www.pokemon.com/ru/" hreflang="ru" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-hn" rel="alternate"/>
#   <link href="https://www.pokemon.com/nl/" hreflang="nl" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-uy" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-bo" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-ar" rel="alternate"/>
#   <link href="https://www.pokemon.com/no/" hreflang="nb" rel="alternate"/>
#   <link href="https://www.pokemon.com/se/" hreflang="sv" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-cr" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-pe" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-co" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-pa" rel="alternate"/>
#   <link href="https://www.pokemon.com/el/" hreflang="es-sv" rel="alternate"/>
#   <link href="https://www.pokemon.com/dk/" hreflang="da" rel="alternate"/>
#
#     <!-- google search appliance meta tags -->
#
# <!-- Adobe Analytics Dynamic Tag Manager -->
#
# <script type="text/javascript">
# var re = /:\/\/[^\/]*?(pokemon.com|openroad.ca)\//,
#     dtmDataLayer = {
#         "SiteValues": {
#             "canonicalPath": "/us/",
#             "pageName": "Homepage",
#             "siteSectionL1": "Landing",
#             "siteSectionL2": "",
#             "siteSectionL3": "",
#             "businessUnit": "pcom",
#             "Language": "en",
#             "Internal/External": document.referrer.match(re) ? "internal" : "external",
#             "SiteErrorType": "",
#             "website": "wwwb11"
#         },
#
#         "Content":{
#             "ContentID":"",  // content tracking
#             "ContentType":"",  // content tracking
#             "ContentVariation":"",  // content tracking
#             "ContentLocation":"",  // content tracking
#             "ContentCategory":"",  // content tracking
#             "ContentDownload":""  // content tracking
#         },
#
#         "ClickElements": {
#             "FormName": "", // form tracking
#             "FormStarts": "", // form tracking
#             "FormComplete": "", // form tracking
#             "TopNav": "", // navigation tracking
#             "LeftNav": "", // navigation tracking
#             "link": "", // link tracking
#             "facet": "", // facet tracking
#             "FavoritePokemon":"", // favorite click tracking
#             "OnlineGame":"", // online game tracking
#             "OnlineTokens":"", // online game tracking
#             "VideoGameFilter":"",  // filter tracking
#             "NewsFilter":"" // filter tracking
#         },
#
#         "internalSearch":{
#             "InternalSearchKeyword":"",  // internal search
#             "InternalSearchRefinement":"",  // internal search
#             "InternalSearchPredictive":"",  // internal search
#             "InternalSearchSelected":"",  // internal search
#             "InternalSearchPosition":"",  // internal search
#             "InternalSearchLoadMore":"",  // internal search
#             "searchResults":""  // internal search
#         },
#
#         "PokedexSearch":{
#             "Keyword":"",  //pokedex search
#             "PokedexSearchType":"",  //pokedex search
#             "PokedexSearchSortBy":"",  //pokedex search
#             "PokedexSearchSelected":"",  //pokedex search
#             "PokedexSurpriseMe":"",  //pokedex search
#             "PokedexLoadMore":"",  //pokedex search
#             "searchResults":""  //pokedex search
#         },
#         "login":{
#             "loginState": 'Logged In' ,
#             "signUpType":""
#         },
#         "SignUp":{
#             "signUpStep":"",
#             "signUpStepID":"",
#             "signUpError": "",
#             "signUpTheme":"",
#             "signUpType":"",
#             "signUpUserType":"",
#             "signUpEntry":""
#         }
# /*
#         "Social":{
#             "SocialMedia":"VALUE"  // social share & subscribe tracking
#         }
# */
#     };
# </script>
#
#
#   <script src="https://assets.pokemon.com/static2/_ui/js/vendor/modernizr.custom.js"></script>
#
#
# <!-- Google Tag Manager -->
# <noscript></noscript></head><body class="us fluid custom-form-elements"><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-V9L7" style="display:none;visibility:hidden" width="0"></iframe>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-V9L7');</script>
# <!-- End Google Tag Manager -->
#
#
#   <!-- START: GOOGLE TAG MANAGER - PAGE DETAILS -->
#
#   <!-- END: GOOGLE TAG MANAGER - PAGE DETAILS -->
#
#
#   <script>
#     // TODO: this should be moved to a better place in the application
#     // needed for image deferred loading in sliders
#     window.addEventListener('load', function(){
#       window.loaded = true;
#     });
#   </script>
#
#
#   <script>
#     window.token = "LIkt4SMMmnG4nltd6WOTCZtLWaGNvjRZT5ZuKxGweNXBVTxFPEdwg7AngVTFSZUy";
#     window.mockAPI = false;
#     window.loginURL = '/us/pokemon-trainer-club/login';
#     window.pokemonUI = window.pokemonUI || {};
#
#     window.pokemonUI.countryCode = 'us'.replace('/', '');
#     window.pokemonUI.api = {
#       'user-details': 'https://www.pokemon.com/api/users/details',
#       'base-url-secure': 'https://www.pokemon.com',
#
#       'gsa': '/us/search/api/'
#
#     };
#
#     window.pokemonUI.config = {
#         'collection': 'production_pokemon_collection'
#     };
#
#     window.pokemonUI.modals = window.pokemonUI.modals || {};
#     window.pokemonUI.modals = {
#       "season": "Season",
#       "episode": "Episode",
#       "legal": "Notice: If you click on the YouTube video above, you will leave Pokemon.com. The Pokémon Company International is not responsible for the content of any linked website that is not operated by The Pokémon Company International. Please note that these websites' privacy policies and security practices may differ from The Pokémon Company International's standards.",
#
#       "twitchlegal": "Notice: If you click on the Twitch video above, you will leave Pokemon.com. The Pokémon Company International is not responsible for the content of any linked website that is not operated by The Pokémon Company International. Please note that these websites' privacy policies and security practices may differ from The Pokémon Company International's standards.",
#     };
#     window.pokemonUI.dictionary = window.pokemonUI.dictionary || {};
#     window.pokemonUI.dictionary.dashboard = {
#       "youRecentlyPurchased": "You Recently Redeemed",
#       "shopMore": "Shop More"
#     };
#     window.pokemonUI.global_dictionary = window.pokemonUI.global_dictionary || {};
#     window.pokemonUI.global_dictionary.search = {
#         'searchUrl': '/us/search/',
#         'GSALanguageCode': 'us'.replace('/', ''),
#         'sortBy': 'Sort by:',
#         'filterBy': 'Filter by:',
#         'selectCategory': 'View All',
#         'mostRelevant': 'Most Relevant',
#         'mostRecent': 'Most Recent',
#         'returnedResults': 'Returned XXXX Results',
#         'recommendedResults': 'Recommended Results',
#         'playGame': 'Play Game',
#         'all': {title : 'View All'},
#         'pokedex' : {title : 'Pokédex'},
#         'videogames' : {title : 'Video Game'},
#         'tcg' : {title : 'Trading Card Game'},
#         'funzone' : {title : 'Online Game'},
#         'animation' : {title : 'Pokémon TV'},
#         'news' : {title : 'News'},
#         'events' : {title : 'Events'},
#         'strategy' : {title : 'Strategy'},
#
#         "numberPrefix": "#"
#     };
#     window.pokemonUI.global_dictionary.datatables = {
#         'search': 'Search:',
#         'previous': 'Previous',
#         'next': 'Next',
#         'emptyTable': "No data is available.",
#         'zeroRecords': "No matching records found."
#     };
#     window.pokemonUI.global_dictionary.errorMessages = {
#
#         'dataError': 'Currently unavailable. Please try again.'
#     };
#     window.pokemonUI['ui-path'] = 'https://assets.pokemon.com/static2/_ui/'
#
#     window.pokemonUI.global_api = {
#
#        'gsa': '/us/search/api/',
#
#        'status-indicators': {
#             'game-server-status': '/api/tcg/game_server_status',
#             'tcgo-in-maintenance': '/api/tcg/in_maintenance_status',
#             'notifications': 'https://www.pokemon.com/api/user/notifications/config'
#         }
#     };
#
#
#
#     window.pokemonUI.cookie = {
#         set: function (name, value, days) {
#             if (days) {
#                 var date = new Date();
#                 date.setTime(date.getTime()+(days*24*60*60*1000));
#                 var expires = "; expires="+date.toGMTString();
#             }
#             else var expires = "";
#             document.cookie = name+"="+value+expires+"; path=/";
#         },
#
#         get:function(name){
#             var nameEQ = name + '=',
#                 ca = document.cookie.split(';'),
#                 c, i = 0, ii = 0;
#
#             for(i = 0, ii = ca.length; i < ii; i++) {
#                 c = ca[i];
#
#                 while(c.charAt(0) === ' '){
#                     c = c.substring(1, c.length);
#                 }
#
#                 if(c.indexOf(nameEQ) === 0){
#                     var value = c.substring(nameEQ.length, c.length);
#                     if (value.charAt(0) == '"' && value.charAt(value.length-1) == '"') {
#                         value = value.substring(1,value.length-1);
#                     }
#                     return value;
#                 }
#             }
#             return null;
#         }
#     };
#
#     window.pokemonUI.cookie.set("django_language", "en", 365);
#
#
#
#
#
#     window.enableDashboard = true;
#
#   </script>
#
#
#
#
#
#
#
#     <link href="https://assets.pokemon.com/static2/_ui/css/homepage.css" rel="stylesheet"/>
#
#
#
#   <script data-main="https://assets.pokemon.com/static2/_ui/js/home.js" src="https://assets.pokemon.com/static2/_ui/js/vendor/require.js"></script>
#
#
#
#
#
# <link href="https://assets.pokemon.com/static2/_ui/css/gus.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://assets.pokemon.com/static2/_ui/css/gus_integration.css" rel="stylesheet"/>
#
#
#
#
#
#     <div id="gus-wrapper">
# <div class="pokemon-gus-container" data-api="https://www.pokemon.com/api/gus/" data-locale="en" data-site="pcom" data-width="913px"></div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="main-filler"></div>
# <nav class="main">
#
#
#
#     <div class="blocker"></div>
#
#     <div class="content-wrapper">
#
#         <div class="nav-bar">
#             <a class="nav-toggle" href="#"><span class="icon icon_hamburger"></span></a>
#
#             <ul class="dashboard-open visible-mobile">
#                 <li class="visible-signed-in">
#                     <a href="/us/pokemon-trainer-club/login">
#                         <div class="avatar-icon-wrapper">
#                             <img alt="View Profile" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-avatar.png"/>
#                         </div>
#                     </a>
#                 </li>
#
#                 <li class="visible-not-signed-in">
#                     <a href="/us/pokemon-trainer-club/login">
#                         <div class="avatar-icon-wrapper">
#                             <img alt="Log In / Sign Up" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>
#                         </div>
#                         <div class="sign-in-text-wrapper sign-in-text-wrapper-mobile">
#                             Log In
#                         </div>
#                     </a>
#                 </li>
#             </ul>
#         </div>
#
#         <ul data-analytics-label="primary-nav">
#
#
#
#
# <li class="home">
#   <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/" target="_self">
#     <span class="fill"></span>
#
#     <span class="icon icon_home">
#
#
#     </span>
#
#     <span class="title title_home">Home</span>
#   </a>
#
#
#
# </li>
#
#
#
# <li class="explore">
#   <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokedex/" target="_self">
#     <span class="fill"></span>
#
#     <span class="icon icon_pokeball">
#
#
#     </span>
#
#     <span class="title title_pokeball">Pokédex</span>
#   </a>
#
#
#
# </li>
#
#
#
# <li class="watch">
#   <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-video-games/" target="_self">
#     <span class="fill"></span>
#
#     <span class="icon icon_joystick">
#
#
#     </span>
#
#     <span class="title title_joystick">Video Games &amp; Apps</span>
#   </a>
#
#
#
# </li>
#
#
#
# <li class="play">
#   <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/" target="_self">
#     <span class="fill"></span>
#
#     <span class="icon icon_cards">
#
#
#     </span>
#
#     <span class="title title_cards">Trading Card Game</span>
#   </a>
#
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#
# <ul class="subnav secondary">
#
#     <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
#         <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#         <a href="#"><span class="title">Trading Card Game</span></a>
#     </li>
#
#
#
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/play-online/" target="_self">Pokémon TCG Online</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/play-online/leaderboards/" target="_self">TCG Online Leaderboards</a>
#
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
#
#
# <li class="attend">
#   <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-episodes/" target="_self">
#     <span class="fill"></span>
#
#     <span class="icon icon_pokemontv">
#
#
#     </span>
#
#     <span class="title title_pokemontv">Pokémon TV</span>
#   </a>
#
#
#
# </li>
#
#
#
# <li class="trade">
#   <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/" target="_self">
#     <span class="fill"></span>
#
#     <span class="icon icon_event">
#
#
#     </span>
#
#     <span class="title title_event">Play! Pokémon Events</span>
#   </a>
#
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#
# <ul class="subnav secondary">
#
#     <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
#         <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#         <a href="#"><span class="title">Play! Pokémon Events</span></a>
#     </li>
#
#
#
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/" target="_self">Play! Pokémon Events</a>
#
#     <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#
# <ul class="subnav tertiary">
#
#     <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
#         <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#         <a href="#"><span class="title">Play! Pokémon Events</span></a>
#     </li>
#
#
#
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/" target="_self">Play! Pokémon Events</a>
#
#     <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#
# <ul class="subnav tertiary">
#
#     <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
#         <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#         <a href="#"><span class="title">Play! Pokémon Events</span></a>
#     </li>
#
#
#
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/find-an-event/" target="_self">Event Locator</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/play-in-a-league/" target="_self">Pokémon League</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pokemon-tournaments/" target="_self">Pokémon Championship Series</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pokemon-tournaments/earn-championship-points/" target="_self">Championship Points</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/leaderboards/" target="_self">Championship Rating and Rankings</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pre-release-tournaments/" target="_self">Prerelease Tournaments</a>
#
#
#
# </li>
#
#
# </ul>
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/" target="_self">About Play! Pokémon</a>
#
#     <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#
# <ul class="subnav tertiary">
#
#     <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
#         <a class="subnav-toggle" href="#"><span class="icon"></span></a>
#         <a href="#"><span class="title">About Play! Pokémon</span></a>
#     </li>
#
#
#
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/play-points/" target="_self">Play! Points</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/tournaments-rules-and-resources/" target="_self">Rules &amp; Resources</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/tournaments-glossary/" target="_self">Play! Pokémon Glossary</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/video-game-glossary/" target="_self">Video Game Glossary</a>
#
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/parents-guide/" target="_self">Parents Guide</a>
#
#
#
# </li>
#
#
# </ul>
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/organize/" target="_self">Organize Events</a>
#
#
#
# </li>
#
#
# </ul>
#
#
# </li>
# <li>
#     <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/leaderboards/" target="_self">Play! Pokémon Leaderboards</a>
#
#
#
# </li>
#
#
# </ul>
#
#
# </li>
#
#
#
# <li class="game last-item">
#   <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-news/" target="_self">
#     <span class="fill"></span>
#
#     <span class="icon icon_news">
#
#
#     </span>
#
#     <span class="title title_news">News</span>
#   </a>
#
#
#
# </li>
#
#
#
#     <li class="search">
#         <div class="search-wrapper">
#             <form action="/search/" id="mobile-nav-site-search-widget" method="GET">
#                 <input id="mobile-search" name="q" placeholder="Search" type="search" value=""/>
#                 <span class="icon icon_search"></span>
#             </form>
#         </div>
#     </li>
# </ul>
#
#
#
#     </div>
#
# </nav>
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="default-background" id="user-dashboard">
#
#     <div class="drawer">
#
#         <nav class="profile-nav hidden-mobile">
#
#             <ul class="dashboard-open">
#                 <li class="visible-not-signed-in sign-up">
#                     <a href="https://club.pokemon.com/us/pokemon-trainer-club/login">
#                         <span class="">
#                             <div class="avatar-icon-wrapper">
#                                 <img alt="Sign In" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>
#                             </div>
#                             <div class="sign-in-text-wrapper">
#                                 Log In
#                             </div>
#                         </span>
#                     </a>
#                 </li>
#
#                 <li class="visible-signed-in">
#                     <a href="/us/pokemon-trainer-club/my-profile/">
#                         <span class="">
#                             <div class="avatar-icon-wrapper">
#                                 <img alt="Profile" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-avatar.png"/>
#                             </div>
#                         </span>
#                     </a>
#                 </li>
#
#                 <li class="visible-signed-in friends-page">
#                     <a href="/us/pokemon-trainer-club/friends/">
#                       <span class="icon icon_friends">
#                             <span class="offscreen">Friends</span>
#                       </span>
#                     </a>
#                 </li>
#
#
#                     <li class="visible-signed-in organizer-link">
#                         <a href="/us/pokemon-trainer-club/play-pokemon/events/">
#                             <span class="">
#                                 <div class="organizer-icon-wrapper">
#                                     <img alt="Profile" class="organizer-icon default" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-builder.png"/>
#                                     <img alt="Profile" class="organizer-icon ie9-hover" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-builder-ie9-hover.png"/>
#                                     <span class="offscreen">Profile</span>
#                                 </div>
#                             </span>
#                         </a>
#                     </li>
#
#
#                 <li class="visible-signed-in sign-in" id="sidebar-logout-button">
#                     <a href="/us/pokemon-trainer-club/logout">
#                         <span>Log Out</span>
#                     </a>
#                 </li>
#
#             </ul>
#             <div class="search">
#                 <a class="icon icon_search" href="">
#                     <span class="offscreen"></span>
#                 </a>
#             </div>
#             <div class="bottom-angle"></div>
#         </nav>
#
#         <div class="dashboard"></div>
#
#     </div>
#
# </div>
#
#
#
#
#
#
#   <div class="container">
#
#
#
#
#
#
#
#
#
#
#
# <section class="mosaic section" data-tile-template="MosaicDefault">
#
#     <script>
#     // For GTM Custom Dimension Tracking
#     // Can't be the first child element that's why it is inside the section
#     window.pokemonMosaicType = 'MosaicDefault';
#     </script>
#
#
#
#     <div class="column-8 push-1" data-tile-position="Main">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-tcg-top-deck-academy-episode-5-whimsicott-shows-heavyweight-power/">
#
#
#    <div class="content-block content-block-full content-hero">
#
#
#
#       <div class="content-hero-wrapper">
#
#
#
#
#
#
#
#         <div class="tile-image-wrapper">
#             <img alt="Top Deck Academy: Small Pokémon Can Do Big Damage, Too" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg"/>
#         </div>
#
#
#       </div>
#
#
#
#
#       <div class="banner banner-gray">
#
#
#
#
#
#       <h3>Top Deck Academy: Small Pokémon Can Do Big Damage, Too</h3>
#       <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-gos-march-community-day-features-fletchling/">
#
#
#    <div class="content-block content-block-half-first">
#
#
#
#
#
#
#
#
#
#         <div class="tile-image-wrapper">
#             <img alt="Fletchling Features in March Community Day" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg"/>
#         </div>
#
#
#
#
#
#
#
#       <div class="banner banner-brown">
#
#
#
#
#
#       <h3>Fletchling Features in March Community Day</h3>
#
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/compete-in-the-spikemuth-cup-online-competition/">
#
#
#    <div class="content-block content-block-half">
#
#
#
#
#
#
#
#
#
#         <div class="tile-image-wrapper">
#             <img alt="Compete in the Spikemuth Cup" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg"/>
#         </div>
#
#
#
#
#
#
#
#       <div class="banner banner-black">
#
#
#
#
#
#       <h3>Compete in the Spikemuth Cup</h3>
#
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#     </div>
#
#     <div class="column-4 push-9" data-tile-position="Right_">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/see-urshifu-tapu-koko-and-more-in-pokemon-tcg-sword-shield-battle-styles/">
#
#
#    <div class="content-block content-block-full">
#
#
#
#
#
#
#
#
#
#         <div class="tile-image-wrapper">
#             <img alt="See Urshifu’s Two Sword &amp; Shield—Battle Styles Cards" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg"/>
#         </div>
#
#
#
#
#
#
#
#       <div class="banner banner-blue">
#
#
#
#
#
#       <h3>See Urshifu’s Two <em>Sword &amp; Shield—Battle Styles</em> Cards</h3>
#
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-journeys-the-series-on-netflix-recap/">
#
#
#    <div class="content-block content-block-full">
#
#
#
#
#       <div class="banner banner-right banner-green">
#
#
#       <div class="tile-image-wrapper">
#         <img alt="Pokémon Journeys: The Series Recap" src="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png"/>
#       </div>
#
#
#     <div class="banner-wrapper">
#
#       <h3><em>Pokémon Journeys: The Series</em> Recap</h3>
#
#
#
#
#
#     </div>
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/take-the-pokemon-tcg-background-pokemon-quiz/">
#
#
#    <div class="content-block content-block-full">
#
#
#
#
#
#
#
#
#
#         <div class="tile-image-wrapper">
#             <img alt="Test Your Pokémon TCG: Sword &amp; Shield Series Knowledge with This Background Pokémon Quiz" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png"/>
#         </div>
#
#
#
#
#
#
#
#       <div class="banner banner-lightpurple">
#
#
#
#
#
#       <h3>Test Your Pokémon TCG: <em>Sword &amp; Shield</em> Series Knowledge with This Background Pokémon Quiz</h3>
#
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#     </div>
#
#     <div class="loader"></div>
#
# </section>
#
#
# <noscript>
#
#         <div>
#             <a href="/us/pokemon-news/pokemon-tcg-top-deck-academy-episode-5-whimsicott-shows-heavyweight-power/">
#                 <h3>Top Deck Academy: Small Pokémon Can Do Big Damage, Too</h3>
#                 <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>
#
#                 <img alt="Top Deck Academy: Small Pokémon Can Do Big Damage, Too" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/see-urshifu-tapu-koko-and-more-in-pokemon-tcg-sword-shield-battle-styles/">
#                 <h3>See Urshifu’s Two <em>Sword &amp; Shield—Battle Styles</em> Cards</h3>
#                 <p></p>
#
#                 <img alt="See Urshifu’s Two &lt;em&gt;Sword &amp; Shield—Battle Styles&lt;/em&gt; Cards" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/pokemon-journeys-the-series-on-netflix-recap/">
#                 <h3><em>Pokémon Journeys: The Series</em> Recap</h3>
#                 <p></p>
#
#                 <img alt="&lt;em&gt;Pokémon Journeys: The Series&lt;/em&gt; Recap" src="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/pokemon-gos-march-community-day-features-fletchling/">
#                 <h3>Fletchling Features in March Community Day</h3>
#                 <p></p>
#
#                 <img alt="Fletchling Features in March Community Day" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/compete-in-the-spikemuth-cup-online-competition/">
#                 <h3>Compete in the Spikemuth Cup</h3>
#                 <p></p>
#
#                 <img alt="Compete in the Spikemuth Cup" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/take-the-pokemon-tcg-background-pokemon-quiz/">
#                 <h3>Test Your Pokémon TCG: <em>Sword &amp; Shield</em> Series Knowledge with This Background Pokémon Quiz</h3>
#                 <p></p>
#
#                 <img alt="Test Your Pokémon TCG: &lt;em&gt;Sword &amp; Shield&lt;/em&gt; Series Knowledge with This Background Pokémon Quiz" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png"/>
#
#             </a>
#         </div>
#
# </noscript>
#
#
#
#
# <section class="slider-widget preload-images" id="pokemon-character-slider">
#
#
#   <div class="slider-title">
#     <div class="column-12 push-1">
#       <h3 class="pokemon-character-slider-title">
#         <span class="notch-left-top-outer"></span>
#         <span class="icon icon_pokeball"></span>
#         Featured Pokémon
#       </h3>
#     </div>
#   </div>
#
#
#   <div class="slider-wrapper">
#     <ul class="slider">
#
#
#
# <li data-analytics-label="Pidgey | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
#
#   <div class="pokedex-bg">16</div>
#   <img alt="Pidgey" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//016.png"/>
#   <div class="mini-profile">
#     <h5>Pidgey
#       <span class="pokedex">16</span>
#     </h5>
#     <dl>
#
#       <dt>Type</dt>
#
#       <dd class="types">
#         <span class="type-label background-color-normal">
#           Normal
#         </span>
#         <span class="type-label background-color-flying">
#           Flying
#         </span>
#       </dd>
#
#       <dt>Abilities</dt>
#
#       <dd class="abilities">
#
#         <span class="ability-label">Keen Eye</span>
#         /
#
#         <span class="ability-label">Tangled Feet</span>
#
#
#       </dd>
#     </dl>
#     <span class="notch-bottom-center-small"></span>
#   </div>
#
#
#   <a class="block-link" href="/us/pokedex/pidgey" style="background-color: #fff; opacity: 0;" title="Pidgey">
#     <span class="offscreen">Pidgey Profile</span>
#   </a>
# </li>
#
#
#
# <li data-analytics-label="Rampardos | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
#
#   <div class="pokedex-bg">409</div>
#   <img alt="Rampardos" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//409.png"/>
#   <div class="mini-profile">
#     <h5>Rampardos
#       <span class="pokedex">409</span>
#     </h5>
#     <dl>
#
#       <dt>Type</dt>
#
#       <dd class="types">
#         <span class="type-label background-color-rock">
#           Rock
#         </span>
#         <span class="type-label background-color-">
#
#         </span>
#       </dd>
#
#       <dt>Abilities</dt>
#
#       <dd class="abilities">
#
#         <span class="ability-label">Mold Breaker</span>
#
#
#       </dd>
#     </dl>
#     <span class="notch-bottom-center-small"></span>
#   </div>
#
#
#   <a class="block-link" href="/us/pokedex/rampardos" style="background-color: #fff; opacity: 0;" title="Rampardos">
#     <span class="offscreen">Rampardos Profile</span>
#   </a>
# </li>
#
#
#
# <li data-analytics-label="Palkia | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
#
#   <div class="pokedex-bg">484</div>
#   <img alt="Palkia" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//484.png"/>
#   <div class="mini-profile">
#     <h5>Palkia
#       <span class="pokedex">484</span>
#     </h5>
#     <dl>
#
#       <dt>Type</dt>
#
#       <dd class="types">
#         <span class="type-label background-color-water">
#           Water
#         </span>
#         <span class="type-label background-color-dragon">
#           Dragon
#         </span>
#       </dd>
#
#       <dt>Abilities</dt>
#
#       <dd class="abilities">
#
#         <span class="ability-label">Pressure</span>
#
#
#       </dd>
#     </dl>
#     <span class="notch-bottom-center-small"></span>
#   </div>
#
#
#   <a class="block-link" href="/us/pokedex/palkia" style="background-color: #fff; opacity: 0;" title="Palkia">
#     <span class="offscreen">Palkia Profile</span>
#   </a>
# </li>
#
#
#
# <li data-analytics-label="Stoutland | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
#
#   <div class="pokedex-bg">508</div>
#   <img alt="Stoutland" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//508.png"/>
#   <div class="mini-profile">
#     <h5>Stoutland
#       <span class="pokedex">508</span>
#     </h5>
#     <dl>
#
#       <dt>Type</dt>
#
#       <dd class="types">
#         <span class="type-label background-color-normal">
#           Normal
#         </span>
#         <span class="type-label background-color-">
#
#         </span>
#       </dd>
#
#       <dt>Abilities</dt>
#
#       <dd class="abilities">
#
#         <span class="ability-label">Intimidate</span>
#         /
#
#         <span class="ability-label">Sand Rush</span>
#
#
#       </dd>
#     </dl>
#     <span class="notch-bottom-center-small"></span>
#   </div>
#
#
# ...
#         </div>
#
#
#
#
#
#
#
#       <div class="banner banner-black">
#
#
#
#
#
#       <h3>Explore the Sinnoh of the Past with <em>Pokémon Legends: Arceus</em></h3>
#       <p>Visit the official site to get a first look at this action-infused RPG adventure.</p>
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
# 	</div>
#
# 	<div class="column-4 push-9 staggered-2" data-tile-position="Right_">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-sword-and-pokemon-shield-max-raid-battles-feature-gigantamax-corviknight-and-gigantamax-hatterene/">
#
#
#    <div class="content-block content-block-full">
#
#
#
#
#
#
#
#
#
#         <div class="tile-image-wrapper">
#             <img alt="Fly High with Pokémon Sword and Pokémon Shield Max Raid Battles" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg"/>
#         </div>
#
#
#
#
#
#
#
#       <div class="banner banner-red">
#
#
#
#
#
#       <h3>Fly High with <em>Pokémon Sword</em> and <em>Pokémon Shield</em> Max Raid Battles</h3>
#       <p>Battle Fairy-type and Flying-type Pokémon in Max Raid Battles between March 1 and April 1.</p>
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/compete-in-the-pokemon-sword-and-pokemon-shield-ranked-battles-march-2021-season/">
#
#
#    <div class="content-block content-block-full">
#
#
#
#
#
#
#
#
#
#         <div class="tile-image-wrapper">
#             <img alt="March Forth in the New Ranked Battles Season" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg"/>
#         </div>
#
#
#
#
#
#
#
#       <div class="banner banner-lightblue">
#
#
#
#
#
#       <h3>March Forth in the New Ranked Battles Season</h3>
#       <p>Take on <em>Pokémon Sword</em> and <em>Pokémon Shield</em> players from around the world to earn in-game rewards during the March season.</p>
#
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#
#     </div>
#
#
#   </a>
#
#
#
#
#
#
#
#
#
#
#
#
# 		<a data-analytics-label="#need-analytics-label" href="/us/pokemon-news/">
# 			<div class="content-block content-block-full">
# 				<div class="color-block color-block-orange">
# 					<h2>View All News</h2>
# 				</div>
#
# 				<div class="banner banner-lightblue dog-ear-br">
# 					<p>Keep up with all the latest developments!</p>
# 				</div>
#
# 			</div>
# 		</a>
#
#
# 	</div>
#
#     <div class="loader"></div>
#
# </section>
#
#
# <noscript>
#
#         <div>
#             <a href="/us/pokemon-news/get-a-showstopping-pikachu-in-pokemon-sword-or-pokemon-shield/">
#                 <h3>Get a Most Melodic Pikachu</h3>
#                 <p>Use this password in &lt;em&gt;Pokémon Sword&lt;/em&gt; or &lt;em&gt;Pokémon Shield&lt;/em&gt; to receive a special Pikachu that knows Sing, a move it can’t ordinarily learn.</p>
#
#                 <img alt="Get a Most Melodic Pikachu" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/distributions/pikachu/sing/pikachu-sing-169-en.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="http://pokemon.com/DiamondPearl">
#                 <h3>Return to the Sinnoh Region</h3>
#                 <p>A classic adventure is back with a modern update in &lt;em&gt;Pokémon Brilliant Diamond&lt;/em&gt; and &lt;em&gt;Pokémon Shining Pearl&lt;/em&gt;.</p>
#
#                 <img alt="Return to the Sinnoh Region" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-brilliant-diamond-shining-pearl/announce/brilliant-diamond-shining-pearl-169-en.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/therian-forme-tornadus-therian-forme-thundurus-and-therian-forme-landorus-will-make-their-pokemon-go-debut-in-the-season-of-legends/">
#                 <h3>Celebrate the Season of Legends in Pokémon GO from March 1 to June 1</h3>
#                 <p>Therian Forme Tornadus, Therian Forme Thundurus, and Therian Forme Landorus will make their Pokémon GO debut.</p>
#
#                 <img alt="Celebrate the Season of Legends in Pokémon GO from March 1 to June 1" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="http://pokemon.com/LegendsArceus">
#                 <h3>Explore the Sinnoh of the Past with <em>Pokémon Legends: Arceus</em></h3>
#                 <p>Visit the official site to get a first look at this action-infused RPG adventure.</p>
#
#                 <img alt="Explore the Sinnoh of the Past with &lt;em&gt;Pokémon Legends: Arceus&lt;/em&gt;" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/pokemon-sword-and-pokemon-shield-max-raid-battles-feature-gigantamax-corviknight-and-gigantamax-hatterene/">
#                 <h3>Fly High with <em>Pokémon Sword</em> and <em>Pokémon Shield</em> Max Raid Battles</h3>
#                 <p>Battle Fairy-type and Flying-type Pokémon in Max Raid Battles between March 1 and April 1.</p>
#
#                 <img alt="Fly High with &lt;em&gt;Pokémon Sword&lt;/em&gt; and &lt;em&gt;Pokémon Shield&lt;/em&gt; Max Raid Battles" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg"/>
#
#             </a>
#         </div>
#
#         <div>
#             <a href="/us/pokemon-news/compete-in-the-pokemon-sword-and-pokemon-shield-ranked-battles-march-2021-season/">
#                 <h3>March Forth in the New Ranked Battles Season</h3>
#                 <p>Take on &lt;em&gt;Pokémon Sword&lt;/em&gt; and &lt;em&gt;Pokémon Shield&lt;/em&gt; players from around the world to earn in-game rewards during the March season.</p>
#
#                 <img alt="March Forth in the New Ranked Battles Season" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg"/>
#
#             </a>
#         </div>
#
# </noscript>
#
#
#
#
#
#
#
#
#
#
#     <!-- end of container -->
#   </div>
#
#
#
#
#
#   <div class="visible-mobile" id="back-to-top">
#     <span class="offscreen">Back to Top</span>
#   </div>
#
#   <div class="footer-divider">
#     <span class="footer-notch"></span>
#   </div>
#
#   <footer class="global-footer">
#     <div class="content-wrapper match-height-tablet">
#
#
#
# <div class="global-footer-links match">
#   <h2><span class="offscreen">The Pokémon Company</span></h2>
#   <ul>
#
#
#       <li>
#         <a href="/us/pokemon-news/" rel="" title="">
#           What's New
#         </a>
#       </li>
#
#       <li>
#         <a href="/us/parents-guide/" rel="" title="">
#           Pokémon Parents Guide
#         </a>
#       </li>
#       <li>
#         <a href="/us/customer-service/" rel="" title="">
#           Customer Service
#         </a>
#       </li>
#       <li>
#         <a href="/us/about-pokemon/" rel="" title="">
#           About Our Company
#         </a>
#       </li>
#
#       <li>
#         <a class="exit-link" href="https://boards.greenhouse.io/pokemoncareers" id="careers-link" rel="https://boards.greenhouse.io/pokemoncareers" target="_blank" title="External: https://boards.greenhouse.io/pokemoncareers">
#           Pokémon Careers
#         </a>
#       </li>
#
#
#     <li>
#       <a href="/us/country-region/" rel="" title="">
#         Select a Country/Region
#         <i class="icon-us"></i>
#       </a>
#     </li>
#     <li>
#       <a class="exit-link" href="https://press.pokemon.com/" id="press-link" rel="https://press.pokemon.com/" target="_blank" title="External: https://press.pokemon.com/">
#         Pokémon Press Site
#       </a>
#     </li>
#
#
#
#   </ul>
# </div>
#
#
#
# <div class="global-footer-social match">
#
#     <div class="footer-social-wrapper">
#         <div class="find-us">
#             <div class="find-us-box">
#
#
#                 <a class="facebook exit-link" href="https://www.facebook.com/pokemon" target="_blank" title="External: https://www.facebook.com/pokemon">
#                     <span class="offscreen">Facebook</span>
#                 </a>
#
#                 <a class="youtube exit-link" href="https://www.youtube.com/user/Pokemon" target="_blank" title="External: https://www.youtube.com/user/Pokemon">
#                     <span class="offscreen">Youtube</span>
#                 </a>
#
#                 <a class="twitter exit-link" href="https://www.twitter.com/pokemon" target="_blank" title="External: https://www.twitter.com/pokemon">
#                     <span class="offscreen">Twitter</span>
#                 </a>
#
#                 <a class="instagram exit-link" href="https://www.instagram.com/pokemon" target="_blank" title="External: https://www.instagram.com/pokemon">
#                     <span class="offscreen">Instagram</span>
#                 </a>
#
#
#                 <a class="pinterest exit-link" href="https://www.pinterest.com/pokemon" target="_blank" title="External: https://www.pinterest.com/pokemon">
#                     <span class="offscreen">Pinterest</span>
#                 </a>
#
#             </div>
#         </div>
#
#     </div>
#
# </div>
#
#
#
#
#
# <div class="global-footer-legal match">
#
#   <div class="footer-legal-wrapper">
#
#     <div id="footer--privacy">
#         <a class="exit-link" href="https://caru.bbbprograms.org/seal/Confirmation/1596150491" target="_blank">
#         </a>
#
#       <ul>
#
#           <li>
#             <a href="/us/terms-of-use/">Terms of Use</a>
#           </li>
#
#           <li>
#             <a href="/us/privacy-notice/">Privacy Notice</a>
#           </li>
#
#           <li>
#             <a href="/us/cookie-page/" id="cookieLink">Cookie Page</a>
#           </li>
#
#           <li>
#             <a href="/us/legal/">Legal Info</a>
#           </li>
#
#
#             <li>
#               <a href="/us/vulnerability-disclosure-program/" id="securityLink">Security</a>
#             </li>
#
#
#         </ul>
#     </div>
#
#     <span>©2021 Pokémon. TM, ®Nintendo.</span>
#
#   </div>
#
# </div>
#
#
#     </div>
#
#   </footer>
#
#
#
#
#
# <div class="popup" id="modal">
# 	<div class="externalLink">
#     <h6>
#
#       You are about to leave a site operated by The Pokémon Company International, Inc.
#
#     </h6>
# 		<p>
#
# The Pokémon Company International is not responsible for the content of any linked website that is not operated by The Pokémon Company International. Please note that these websites' privacy policies and security practices may differ from The Pokémon Company International's standards.
#
#     </p>
# 		<div class="buttons-wrapper">
# 			<a class="button button-green arrow-right continueBtn" href="#">
#
#         Continue
#
#       </a>
# 			<a class="button button-darkgray arrow-left closeBtn" href="#">
#
#         Cancel
#
#       </a>
# 		</div>
# 	</div>
# </div>
#
# <div class="popup" id="pokemon-center-modal">
# 	<div class="externalLink centerLink">
#     <h6>
#       Click Continue to visit PokemonCenter.com, our official online shop.
#     </h6>
#     <h6>
#       The privacy and security policies differ.
#     </h6>
# 		<div class="buttons-wrapper">
# 			<a class="button button-green arrow-right continueBtn" href="#">
#
#         Continue
#
#       </a>
# 			<a class="button button-darkgray arrow-left closeBtn" href="#" target="_blank">
#
#         Cancel
#
#       </a>
# 		</div>
# 	</div>
# </div>
#
# <div class="popup" id="site-search-modal">
#
# 	<form class="form-analytics" id="site-search-widget" name="site-search-modal">
# 		<span class="search"><input autocomplete="off" id="site-search-widget-term" name="search" placeholder="Search" type="search"/></span>
# 		<span class="submit icon icon_search"><input id="site-search-widget-submit" type="submit" value=""/></span>
#         <div id="modal-search-results"></div>
# 	</form>
# </div>
#
# <div class="popup" id="report-screen-name-success-modal">
#   <h6>Report Inappropriate Screen Name</h6>
#
#   <div class="modalBox">
#     <img alt="" class="hidden-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/external_link_bumper.png"/>
#
#     <p>
#     Pokemon.com administrators have been notified and will review the screen name for compliance with the Terms of Use.
#     </p>
#
#     <div class="buttons-wrapper">
#       <a class="button button-orange closeBtn" href="#">
#         Close
#       </a>
#     </div>
#   </div>
# </div>
#
# <div class="popup" id="report-screen-name-failure-modal">
#   <h6>Report Inappropriate Screen Name</h6>
#
#   <div class="modalBox">
#     <img alt="" class="hidden-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/external_link_bumper.png"/>
#
#     <p>
#     Your request could not be completed. Please try again. If the problem persists, please contact Customer Support.
#     </p>
#
#     <div class="buttons-wrapper">
#       <a class="button button-orange closeBtn" href="#">
#         Close
#       </a>
#     </div>
#   </div>
# </div>
#
# <div class="popupScreen" id="popupScreen"></div>
#
#
#
#
# <div class="popup" id="video-modal">
# <span class="watch-token-info"><span class="token_icon"></span><p class="token_verbal">You've been awarded <span class="token_amount">0</span> Token(s) for watching Pokémon TV!</p></span>
#     <div class="video-modal-wrapper">
#
#         <header class="video-header">
#             <h4 id="episodeInfo">
#
#             </h4>
#             <!-- HEADLINE -->
#             <h1 id="episodeTitle"></h1>
#         </header>
#
#         <div class="video-container">
#         </div>
#
#         <p class="hidden-text"><strong>Views: <span id="videoViews"></span></strong></p>
#         <p class="legal"></p>
#
#         <p class="video-summary">
#
#         </p>
#
#
#
#         <a class="closeBtn button button-orange no-arrow right" href="#"><i class="icon icon_multiply"></i> Close</a>
#
#     </div>
#
# </div>
#
#
#
# <script type="text/javascript">
# if (typeof _satellite !== "undefined") {
#   _satellite.pageBottom();
# }
# </script>
#
#
#
#
#
#
#
#
#
# </body></html>

# %% [markdown]
# - We can also use the prettify() function from BeautifulSoup:

# %%
def makeprettysoup(response):
    return BeautifulSoup(response.content, 'html5lib').prettify()

makeprettysoup(response)
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <script type="text/javascript">\n   (window.NREUM||(NREUM={})).loader_config={xpid:"VQ4OWFZXGwIAXFZTBgI=",licenseKey:"ba34eb72cb",applicationID:"1087113"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(27),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{l?l-=1:o(c||new UncaughtException(t,e,n),!0)}catch(u){try{i("ierr",[u,s.now(),!0])}catch(d){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(28),c=t("ee"),s=t("loader"),u=t("gos"),f=window.onerror,d=!1,p="nr@seenError",l=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(l+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(u(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,T=g.hash,this[f]=y.now()}function o(){L--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[f],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",u="-body",f="fn"+c,d="fn"+s,p="cb"+c,l="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),P=t(14),M=t(9),S=t("ee"),C=S.get("tracer");t(16),y.features.spa=!0;var T,L=0;S.on(f,r),b.on(p,r),M.on(p,r),S.on(d,o),b.on(l,o),M.on(l,o),S.buffer([f,d,"xhr-done","xhr-resolved"]),R.buffer([f]),O.buffer(["setTimeout"+s,"clearTimeout"+c,f]),P.buffer([f,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+u+c,m+u+s]),E.buffer(["newURL"]),x.buffer([f]),b.buffer(["propagate",p,l,"executor-err","resolve"+c]),C.buffer([f,"no-"+f]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+c),a(S,"xhr-resolved"),a(S,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",u="addEventListener",f="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,fu ...

# %% [markdown]
# #### 2. Create a `BeautifulSoup` object and navigate the data structure:

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQ4OWFZXGwIAXFZTBgI=",licenseKey:"ba34eb72cb",applicationID:"1087113"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(27),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{l?l-=1:o(c||new UncaughtException(t,e,n),!0)}catch(u){try{i("ierr",[u,s.now(),!0])}catch(d){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(28),c=t("ee"),s=t("loader"),u=t("gos"),f=window.onerror,d=!1,p="nr@seenError",l=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(l+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(u(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,T=g.hash,this[f]=y.now()}function o(){L--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[f],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",u="-body",f="fn"+c,d="fn"+s,p="cb"+c,l="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),P=t(14),M=t(9),S=t("ee"),C=S.get("tracer");t(16),y.features.spa=!0;var T,L=0;S.on(f,r),b.on(p,r),M.on(p,r),S.on(d,o),b.on(l,o),M.on(l,o),S.buffer([f,d,"xhr-done","xhr-resolved"]),R.buffer([f]),O.buffer(["setTimeout"+s,"clearTimeout"+c,f]),P.buffer([f,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+u+c,m+u+s]),E.buffer(["newURL"]),x.buffer([f]),b.buffer(["propagate",p,l,"executor-err","resolve"+c]),C.buffer([f,"no-"+f]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+c),a(S,"xhr-resolved"),a(S,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",u="addEventListener",f="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),"requestAnimat ...
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="en" name="language"/>
# <link href="https://assets.pokemon.com/static2/_ui/img/favicon.ico" rel="shortcut icon"/>
# <title>The Official Pokémon Website | Pokemon.com |
#
#     Explore the World of Pokémon
#
# </title>
# <meta content="The official source for Pokémon news and information on the Pokémon Trading Card Game, apps, video games, animation, and the Pokédex." name="description"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="https://assets.pokemon.com/static2/_ui/css/main.css" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css?family=Roboto:400,700" rel="stylesheet" type="text/css"/>
# <link href="https://www.pokemon.com/fr/" hreflang="fr" rel="alternate"/>
# <link href="https://www.pokemon.com/us/" hreflang="en" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-do" rel="alternate"/>
# <link href="https://www.pokemon.com/de/" hreflang="de" rel="alternate"/>
# <link href="https://www.pokemon.com/it/" hreflang="it" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-py" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-cl" rel="alternate"/>
# <link href="https://www.pokemon.com/br/" hreflang="pt-br" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-gt" rel="alternate"/>
# <link href="https://www.pokemon.com/fi/" hreflang="fi" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-mx" rel="alternate"/>
# <link href="https://www.pokemon.com/jp/" hreflang="ja" rel="alternate"/>
# <link href="https://www.pokemon.com/es/" hreflang="es" rel="alternate"/>
# <link href="https://www.pokemon.com/uk/" hreflang="en-gb" rel="alternate"/>
# <link href="https://www.pokemon.com/ru/" hreflang="ru" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-hn" rel="alternate"/>
# <link href="https://www.pokemon.com/nl/" hreflang="nl" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-uy" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-bo" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-ar" rel="alternate"/>
# <link href="https://www.pokemon.com/no/" hreflang="nb" rel="alternate"/>
# <link href="https://www.pokemon.com/se/" hreflang="sv" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-cr" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-pe" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-co" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-pa" rel="alternate"/>
# <link href="https://www.pokemon.com/el/" hreflang="es-sv" rel="alternate"/>
# <link href="https://www.pokemon.com/dk/" hreflang="da" rel="alternate"/>
# <!-- google search appliance meta tags -->
# <!-- Adobe Analytics Dynamic Tag Manager -->
# <script type="text/javascript">
# var re = /:\/\/[^\/]*?(pokemon.com|openroad.ca)\//,
#     dtmDataLayer = {
#         "SiteValues": {
#             "canonicalPath": "/us/",
#             "pageName": "Homepage",
#             "siteSectionL1": "Landing",
#             "siteSectionL2": "",
#             "siteSectionL3": "",
#             "businessUnit": "pcom",
#             "Language": "en",
#             "Internal/External": document.referrer.match(re) ? "internal" : "external",
#             "SiteErrorType": "",
#             "website": "wwwb11"
#         },
#
#         "Content":{
#             "ContentID":"",  // content tracking
#             "ContentType":"",  // content tracking
#             "ContentVariation":"",  // content tracking
#             "ContentLocation":"",  // content tracking
#             "ContentCategory":"",  // content tracking
#             "ContentDownload":""  // content tracking
#         },
#
#         "ClickElements": {
#             "FormName": "", // form tracking
#             "FormStarts": "", // form tracking
#             "FormComplete": "", // form tracking
#             "TopNav": "", // navigation tracking
#             "LeftNav": "", // navigation tracking
#             "link": "", // link tracking
#             "facet": "", // facet tracking
#             "FavoritePokemon":"", // favorite click tracking
#             "OnlineGame":"", // online game tracking
#             "OnlineTokens":"", // online game tracking
#             "VideoGameFilter":"",  // filter tracking
#             "NewsFilter":"" // filter tracking
#         },
#
#         "internalSearch":{
#             "InternalSearchKeyword":"",  // internal search
#             "InternalSearchRefinement":"",  // internal search
#             "InternalSearchPredictive":"",  // internal search
#             "InternalSearchSelected":"",  // internal search
#             "InternalSearchPosition":"",  // internal search
#             "InternalSearchLoadMore":"",  // internal search
#             "searchResults":""  // internal search
#         },
#
#         "PokedexSearch":{
#             "Keyword":"",  //pokedex search
#             "PokedexSearchType":"",  //pokedex search
#             "PokedexSearchSortBy":"",  //pokedex search
#             "PokedexSearchSelected":"",  //pokedex search
#             "PokedexSurpriseMe":"",  //pokedex search
#             "PokedexLoadMore":"",  //pokedex search
#             "searchResults":""  //pokedex search
#         },
#         "login":{
#             "loginState": 'Logged In' ,
#             "signUpType":""
#         },
#         "SignUp":{
#             "signUpStep":"",
#             "signUpStepID":"",
#             "signUpError": "",
#             "signUpTheme":"",
#             "signUpType":"",
#             "signUpUserType":"",
#             "signUpEntry":""
#         }
# /*
#         "Social":{
#             "SocialMedia":"VALUE"  // social share & subscribe tracking
#         }
# */
#     };
# </script>
# <script src="https://assets.pokemon.com/static2/_ui/js/vendor/modernizr.custom.js"></script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-V9L7" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-V9L7');</script>
# <!-- End Google Tag Manager -->
# <!-- START: GOOGLE TAG MANAGER - PAGE DETAILS -->
# <!-- END: GOOGLE TAG MANAGER - PAGE DETAILS -->
# <script>
#     // TODO: this should be moved to a better place in the application
#     // needed for image deferred loading in sliders
#     window.addEventListener('load', function(){
#       window.loaded = true;
#     });
#   </script>
# <script>
#     window.token = "LIkt4SMMmnG4nltd6WOTCZtLWaGNvjRZT5ZuKxGweNXBVTxFPEdwg7AngVTFSZUy";
#     window.mockAPI = false;
#     window.loginURL = '/us/pokemon-trainer-club/login';
#     window.pokemonUI = window.pokemonUI || {};
#
#     window.pokemonUI.countryCode = 'us'.replace('/', '');
#     window.pokemonUI.api = {
#       'user-details': 'https://www.pokemon.com/api/users/details',
#       'base-url-secure': 'https://www.pokemon.com',
#
#       'gsa': '/us/search/api/'
#
#     };
#
#     window.pokemonUI.config = {
#         'collection': 'production_pokemon_collection'
#     };
#
#     window.pokemonUI.modals = window.pokemonUI.modals || {};
#     window.pokemonUI.modals = {
#       "season": "Season",
#       "episode": "Episode",
#       "legal": "Notice: If you click on the YouTube video above, you will leave Pokemon.com. The Pokémon Company International is not responsible for the content of any linked website that is not operated by The Pokémon Company International. Please note that these websites' privacy policies and security practices may differ from The Pokémon Company International's standards.",
#
#       "twitchlegal": "Notice: If you click on the Twitch video above, you will leave Pokemon.com. The Pokémon Company International is not responsible for the content of any linked website that is not operated by The Pokémon Company International. Please note that these websites' privacy policies and security practices may differ from The Pokémon Company International's standards.",
#     };
#     window.pokemonUI.dictionary = window.pokemonUI.dictionary || {};
#     window.pokemonUI.dictionary.dashboard = {
#       "youRecentlyPurchased": "You Recently Redeemed",
#       "shopMore": "Shop More"
#     };
#     window.pokemonUI.global_dictionary = window.pokemonUI.global_dictionary || {};
#     window.pokemonUI.global_dictionary.search = {
#         'searchUrl': '/us/search/',
#         'GSALanguageCode': 'us'.replace('/', ''),
#         'sortBy': 'Sort by:',
#         'filterBy': 'Filter by:',
#         'selectCategory': 'View All',
#         'mostRelevant': 'Most Relevant',
#         'mostRecent': 'Most Recent',
#         'returnedResults': 'Returned XXXX Results',
#         'recommendedResults': 'Recommended Results',
#         'playGame': 'Play Game',
#         'all': {title : 'View All'},
#         'pokedex' : {title : 'Pokédex'},
#         'videogames' : {title : 'Video Game'},
#         'tcg' : {title : 'Trading Card Game'},
#         'funzone' : {title : 'Online Game'},
#         'animation' : {title : 'Pokémon TV'},
#         'news' : {title : 'News'},
#         'events' : {title : 'Events'},
#         'strategy' : {title : 'Strategy'},
#
#         "numberPrefix": "#"
#     };
#     window.pokemonUI.global_dictionary.datatables = {
#         'search': 'Search:',
#         'previous': 'Previous',
#         'next': 'Next',
#         'emptyTable': "No data is available.",
#         'zeroRecords': "No matching records found."
#     };
#     window.pokemonUI.global_dictionary.errorMessages = {
#
#         'dataError': 'Currently unavailable. Please try again.'
#     };
#     window.pokemonUI['ui-path'] = 'https://assets.pokemon.com/static2/_ui/'
#
#     window.pokemonUI.global_api = {
#
#        'gsa': '/us/search/api/',
#
#        'status-indicators': {
#             'game-server-status': '/api/tcg/game_server_status',
#             'tcgo-in-maintenance': '/api/tcg/in_maintenance_status',
#             'notifications': 'https://www.pokemon.com/api/user/notifications/config'
#         }
#     };
#
#
#
#     window.pokemonUI.cookie = {
#         set: function (name, value, days) {
#             if (days) {
#                 var date = new Date();
#                 date.setTime(date.getTime()+(days*24*60*60*1000));
#                 var expires = "; expires="+date.toGMTString();
#             }
#             else var expires = "";
#             document.cookie = name+"="+value+expires+"; path=/";
#         },
#
#         get:function(name){
#             var nameEQ = name + '=',
#                 ca = document.cookie.split(';'),
#                 c, i = 0, ii = 0;
#
#             for(i = 0, ii = ca.length; i < ii; i++) {
#                 c = ca[i];
#
#                 while(c.charAt(0) === ' '){
#                     c = c.substring(1, c.length);
#                 }
#
#                 if(c.indexOf(nameEQ) === 0){
#                     var value = c.substring(nameEQ.length, c.length);
#                     if (value.charAt(0) == '"' && value.charAt(value.length-1) == '"') {
#                         value = value.substring(1,value.length-1);
#                     }
#                     return value;
#                 }
#             }
#             return null;
#         }
#     };
#
#     window.pokemonUI.cookie.set("django_language", "en", 365);
#
#
#
#
#
#     window.enableDashboard = true;
#
#   </script>
# <link href="https://assets.pokemon.com/static2/_ui/css/homepage.css" rel="stylesheet"/>
# <script data-main="https://assets.pokemon.com/static2/_ui/js/home.js" src="https://assets.pokemon.com/static2/_ui/js/vendor/require.js"></script>
# <link href="https://assets.pokemon.com/static2/_ui/css/gus.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://assets.pokemon.com/static2/_ui/css/gus_integration.css" rel="stylesheet"/>
# </head>
# <body class="us fluid custom-form-elements">
# <div id="gus-wrapper">
# <div class="pokemon-gus-container" data-api="https://www.pokemon.com/api/gus/" data-locale="en" data-site="pcom" data-width="913px"></div>
# </div>
# <div class="main-filler"></div>
# <nav class="main">
# <div class="blocker"></div>
# <div class="content-wrapper">
# <div class="nav-bar">
# <a class="nav-toggle" href="#"><span class="icon icon_hamburger"></span></a>
# <ul class="dashboard-open visible-mobile">
# <li class="visible-signed-in">
# <a href="/us/pokemon-trainer-club/login">
# <div class="avatar-icon-wrapper">
# <img alt="View Profile" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-avatar.png"/>
# </div>
# </a>
# </li>
# <li class="visible-not-signed-in">
# <a href="/us/pokemon-trainer-club/login">
# <div class="avatar-icon-wrapper">
# <img alt="Log In / Sign Up" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>
# </div>
# <div class="sign-in-text-wrapper sign-in-text-wrapper-mobile">
#                             Log In
#                         </div>
# </a>
# </li>
# </ul>
# </div>
# <ul data-analytics-label="primary-nav">
# <li class="home">
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/" target="_self">
# <span class="fill"></span>
# <span class="icon icon_home">
# </span>
# <span class="title title_home">Home</span>
# </a>
# </li>
# <li class="explore">
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokedex/" target="_self">
# <span class="fill"></span>
# <span class="icon icon_pokeball">
# </span>
# <span class="title title_pokeball">Pokédex</span>
# </a>
# </li>
# <li class="watch">
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-video-games/" target="_self">
# <span class="fill"></span>
# <span class="icon icon_joystick">
# </span>
# <span class="title title_joystick">Video Games &amp; Apps</span>
# </a>
# </li>
# <li class="play">
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/" target="_self">
# <span class="fill"></span>
# <span class="icon icon_cards">
# </span>
# <span class="title title_cards">Trading Card Game</span>
# </a>
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <ul class="subnav secondary">
# <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <a href="#"><span class="title">Trading Card Game</span></a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/play-online/" target="_self">Pokémon TCG Online</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/play-online/leaderboards/" target="_self">TCG Online Leaderboards</a>
# </li>
# </ul>
# </li>
# <li class="attend">
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-episodes/" target="_self">
# <span class="fill"></span>
# <span class="icon icon_pokemontv">
# </span>
# <span class="title title_pokemontv">Pokémon TV</span>
# </a>
# </li>
# <li class="trade">
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/" target="_self">
# <span class="fill"></span>
# <span class="icon icon_event">
# </span>
# <span class="title title_event">Play! Pokémon Events</span>
# </a>
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <ul class="subnav secondary">
# <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <a href="#"><span class="title">Play! Pokémon Events</span></a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/" target="_self">Play! Pokémon Events</a>
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <ul class="subnav tertiary">
# <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <a href="#"><span class="title">Play! Pokémon Events</span></a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/" target="_self">Play! Pokémon Events</a>
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <ul class="subnav tertiary">
# <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <a href="#"><span class="title">Play! Pokémon Events</span></a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/find-an-event/" target="_self">Event Locator</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/play-in-a-league/" target="_self">Pokémon League</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pokemon-tournaments/" target="_self">Pokémon Championship Series</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pokemon-tournaments/earn-championship-points/" target="_self">Championship Points</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/leaderboards/" target="_self">Championship Rating and Rankings</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pre-release-tournaments/" target="_self">Prerelease Tournaments</a>
# </li>
# </ul>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/" target="_self">About Play! Pokémon</a>
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <ul class="subnav tertiary">
# <li class="subnav-title" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft">
# <a class="subnav-toggle" href="#"><span class="icon"></span></a>
# <a href="#"><span class="title">About Play! Pokémon</span></a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/play-points/" target="_self">Play! Points</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/tournaments-rules-and-resources/" target="_self">Rules &amp; Resources</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/tournaments-glossary/" target="_self">Play! Pokémon Glossary</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/video-game-glossary/" target="_self">Video Game Glossary</a>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/parents-guide/" target="_self">Parents Guide</a>
# </li>
# </ul>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/organize/" target="_self">Organize Events</a>
# </li>
# </ul>
# </li>
# <li>
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/leaderboards/" target="_self">Play! Pokémon Leaderboards</a>
# </li>
# </ul>
# </li>
# <li class="game last-item">
# <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-news/" target="_self">
# <span class="fill"></span>
# <span class="icon icon_news">
# </span>
# <span class="title title_news">News</span>
# </a>
# </li>
# <li class="search">
# <div class="search-wrapper">
# <form action="/search/" id="mobile-nav-site-search-widget" method="GET">
# <input id="mobile-nav-site-search-widget-term" name="q" placeholder="Search" type="search" value=""/>
# <span class="icon icon_search"></span>
# </form>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# <div class="default-background" id="user-dashboard">
# <div class="drawer">
# <nav class="profile-nav hidden-mobile">
# <ul class="dashboard-open">
# <li class="visible-not-signed-in sign-up">
# <a href="https://club.pokemon.com/us/pokemon-trainer-club/login">
# <span class="">
# <div class="avatar-icon-wrapper">
# <img alt="Sign In" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>
# </div>
# <div class="sign-in-text-wrapper">
#                                 Log In
#                             </div>
# </span>
# </a>
# </li>
# <li class="visible-signed-in">
# <a href="/us/pokemon-trainer-club/my-profile/">
# <span class="">
# <div class="avatar-icon-wrapper">
# <img alt="Profile" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-avatar.png"/>
# </div>
# </span>
# </a>
# </li>
# <li class="visible-signed-in friends-page">
# <a href="/us/pokemon-trainer-club/friends/">
# <span class="icon icon_friends">
# <span class="offscreen">Friends</span>
# </span>
# </a>
# </li>
# <li class="visible-signed-in organizer-link">
# <a href="/us/pokemon-trainer-club/play-pokemon/events/">
# <span class="">
# <div class="organizer-icon-wrapper">
# <img alt="Profile" class="organizer-icon default" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-builder.png"/>
# <img alt="Profile" class="organizer-icon ie9-hover" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-builder-ie9-hover.png"/>
# <span class="offscreen">Profile</span>
# </div>
# </span>
# </a>
# </li>
# <li class="visible-signed-in sign-in" id="sidebar-logout-button">
# <a href="/us/pokemon-trainer-club/logout">
# <span>Log Out</span>
# </a>
# </li>
# </ul>
# <div class="search">
# <a class="icon icon_search" href="">
# <span class="offscreen"></span>
# </a>
# </div>
# <div class="bottom-angle"></div>
# </nav>
# <div class="dashboard"></div>
# </div>
# </div>
# <div class="container">
# <section class="mosaic section" data-tile-template="MosaicDefault">
# <script>
#     // For GTM Custom Dimension Tracking
#     // Can't be the first child element that's why it is inside the section
#     window.pokemonMosaicType = 'MosaicDefault';
#     </script>
# <div class="column-8 push-1" data-tile-position="Main">
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-tcg-top-deck-academy-episode-5-whimsicott-shows-heavyweight-power/">
# <div class="content-block content-block-full content-hero">
# <div class="content-hero-wrapper">
# <div class="tile-image-wrapper">
# <img alt="Top Deck Academy: Small Pokémon Can Do Big Damage, Too" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg"/>
# </div>
# </div>
# <div class="banner banner-gray">
# <h3>Top Deck Academy: Small Pokémon Can Do Big Damage, Too</h3>
# <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>
# </div>
# </div>
# </a>
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-gos-march-community-day-features-fletchling/">
# <div class="content-block content-block-half-first">
# <div class="tile-image-wrapper">
# <img alt="Fletchling Features in March Community Day" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg"/>
# </div>
# <div class="banner banner-brown">
# <h3>Fletchling Features in March Community Day</h3>
# </div>
# </div>
# </a>
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/compete-in-the-spikemuth-cup-online-competition/">
# <div class="content-block content-block-half">
# <div class="tile-image-wrapper">
# <img alt="Compete in the Spikemuth Cup" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg"/>
# </div>
# <div class="banner banner-black">
# <h3>Compete in the Spikemuth Cup</h3>
# </div>
# </div>
# </a>
# </div>
# <div class="column-4 push-9" data-tile-position="Right_">
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/see-urshifu-tapu-koko-and-more-in-pokemon-tcg-sword-shield-battle-styles/">
# <div class="content-block content-block-full">
# <div class="tile-image-wrapper">
# <img alt="See Urshifu’s Two Sword &amp; Shield—Battle Styles Cards" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg"/>
# </div>
# <div class="banner banner-blue">
# <h3>See Urshifu’s Two <em>Sword &amp; Shield—Battle Styles</em> Cards</h3>
# </div>
# </div>
# </a>
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-journeys-the-series-on-netflix-recap/">
# <div class="content-block content-block-full">
# <div class="banner banner-right banner-green">
# <div class="tile-image-wrapper">
# <img alt="Pokémon Journeys: The Series Recap" src="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png"/>
# </div>
# <div class="banner-wrapper">
# <h3><em>Pokémon Journeys: The Series</em> Recap</h3>
# </div>
# </div>
# </div>
# </a>
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/take-the-pokemon-tcg-background-pokemon-quiz/">
# <div class="content-block content-block-full">
# <div class="tile-image-wrapper">
# <img alt="Test Your Pokémon TCG: Sword &amp; Shield Series Knowledge with This Background Pokémon Quiz" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png"/>
# </div>
# <div class="banner banner-lightpurple">
# <h3>Test Your Pokémon TCG: <em>Sword &amp; Shield</em> Series Knowledge with This Background Pokémon Quiz</h3>
# </div>
# </div>
# </a>
# </div>
# <div class="loader"></div>
# </section>
# <noscript>
# <div>
# <a href="/us/pokemon-news/pokemon-tcg-top-deck-academy-episode-5-whimsicott-shows-heavyweight-power/">
# <h3>Top Deck Academy: Small Pokémon Can Do Big Damage, Too</h3>
# <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>
# <img alt="Top Deck Academy: Small Pokémon Can Do Big Damage, Too" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/see-urshifu-tapu-koko-and-more-in-pokemon-tcg-sword-shield-battle-styles/">
# <h3>See Urshifu’s Two <em>Sword &amp; Shield—Battle Styles</em> Cards</h3>
# <p></p>
# <img alt="See Urshifu’s Two &lt;em&gt;Sword &amp; Shield—Battle Styles&lt;/em&gt; Cards" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/pokemon-journeys-the-series-on-netflix-recap/">
# <h3><em>Pokémon Journeys: The Series</em> Recap</h3>
# <p></p>
# <img alt="&lt;em&gt;Pokémon Journeys: The Series&lt;/em&gt; Recap" src="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/pokemon-gos-march-community-day-features-fletchling/">
# <h3>Fletchling Features in March Community Day</h3>
# <p></p>
# <img alt="Fletchling Features in March Community Day" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/compete-in-the-spikemuth-cup-online-competition/">
# <h3>Compete in the Spikemuth Cup</h3>
# <p></p>
# <img alt="Compete in the Spikemuth Cup" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/take-the-pokemon-tcg-background-pokemon-quiz/">
# <h3>Test Your Pokémon TCG: <em>Sword &amp; Shield</em> Series Knowledge with This Background Pokémon Quiz</h3>
# <p></p>
# <img alt="Test Your Pokémon TCG: &lt;em&gt;Sword &amp; Shield&lt;/em&gt; Series Knowledge with This Background Pokémon Quiz" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png">
# </img></a>
# </div>
# </noscript>
# <section class="slider-widget preload-images" id="pokemon-character-slider">
# <div class="slider-title">
# <div class="column-12 push-1">
# <h3 class="pokemon-character-slider-title">
# <span class="notch-left-top-outer"></span>
# <span class="icon icon_pokeball"></span>
#         Featured Pokémon
#       </h3>
# </div>
# </div>
# <div class="slider-wrapper">
# <ul class="slider">
# <li data-analytics-label="Pidgey | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">16</div>
# <img alt="Pidgey" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//016.png"/>
# <div class="mini-profile">
# <h5>Pidgey
#       <span class="pokedex">16</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-normal">
#           Normal
#         </span>
# <span class="type-label background-color-flying">
#           Flying
#         </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Keen Eye</span>
#         /
#
#         <span class="ability-label">Tangled Feet</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/pidgey" style="background-color: #fff; opacity: 0;" title="Pidgey">
# <span class="offscreen">Pidgey Profile</span>
# </a>
# </li>
# <li data-analytics-label="Rampardos | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">409</div>
# <img alt="Rampardos" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//409.png"/>
# <div class="mini-profile">
# <h5>Rampardos
#       <span class="pokedex">409</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-rock">
#           Rock
#         </span>
# <span class="type-label background-color-">
# </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Mold Breaker</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/rampardos" style="background-color: #fff; opacity: 0;" title="Rampardos">
# <span class="offscreen">Rampardos Profile</span>
# </a>
# </li>
# <li data-analytics-label="Palkia | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">484</div>
# <img alt="Palkia" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//484.png"/>
# <div class="mini-profile">
# <h5>Palkia
#       <span class="pokedex">484</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-water">
#           Water
#         </span>
# <span class="type-label background-color-dragon">
#           Dragon
#         </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Pressure</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/palkia" style="background-color: #fff; opacity: 0;" title="Palkia">
# <span class="offscreen">Palkia Profile</span>
# </a>
# </li>
# <li data-analytics-label="Stoutland | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">508</div>
# <img alt="Stoutland" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//508.png"/>
# <div class="mini-profile">
# <h5>Stoutland
#       <span class="pokedex">508</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-normal">
#           Normal
#         </span>
# <span class="type-label background-color-">
# </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Intimidate</span>
#         /
#
#         <span class="ability-label">Sand Rush</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/stoutland" style="background-color: #fff; opacity: 0;" title="Stoutland">
# <span class="offscreen">Stoutland Profile</span>
# </a>
# </li>
# <li data-analytics-label="Duosion | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">578</div>
# <img alt="Duosion" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//578.png"/>
# <div class="mini-profile">
# <h5>Duosion
#       <span class="pokedex">578</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-psychic">
#           Psychic
#         </span>
# <span class="type-label background-color-">
# </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Magic Guard</span>
#         /
#
#         <span class="ability-label">Overcoat</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/duosion" style="background-color: #fff; opacity: 0;" title="Duosion">
# <span class="offscreen">Duosion Profile</span>
# </a>
# </li>
# <li data-analytics-label="Delphox | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">655</div>
# <img alt="Delphox" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//655.png"/>
# <div class="mini-profile">
# <h5>Delphox
#       <span class="pokedex">655</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-fire">
#           Fire
#         </span>
# <span class="type-label background-color-psychic">
#           Psychic
#         </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Blaze</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/delphox" style="background-color: #fff; opacity: 0;" title="Delphox">
# <span class="offscreen">Delphox Profile</span>
# </a>
# </li>
# <li data-analytics-label="Aegislash | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">681</div>
# <img alt="Aegislash" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//681.png"/>
# <div class="mini-profile">
# <h5>Aegislash
#       <span class="pokedex">681</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-steel">
#           Steel
#         </span>
# <span class="type-label background-color-ghost">
#           Ghost
#         </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Stance Change</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/aegislash" style="background-color: #fff; opacity: 0;" title="Aegislash">
# <span class="offscreen">Aegislash Profile</span>
# </a>
# </li>
# <li data-analytics-label="Toucannon | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">733</div>
# <img alt="Toucannon" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//733.png"/>
# <div class="mini-profile">
# <h5>Toucannon
#       <span class="pokedex">733</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-normal">
#           Normal
#         </span>
# <span class="type-label background-color-flying">
#           Flying
#         </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Keen Eye</span>
#         /
#
#         <span class="ability-label">Skill Link</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/toucannon" style="background-color: #fff; opacity: 0;" title="Toucannon">
# <span class="offscreen">Toucannon Profile</span>
# </a>
# </li>
# <li data-analytics-label="Komala | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">775</div>
# <img alt="Komala" class="pokemon-character preload" data-preload-src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//775.png"/>
# <div class="mini-profile">
# <h5>Komala
#       <span class="pokedex">775</span>
# </h5>
# <dl>
# <dt>Type</dt>
# <dd class="types">
# <span class="type-label background-color-normal">
#           Normal
#         </span>
# <span class="type-label background-color-">
# </span>
# </dd>
# <dt>Abilities</dt>
# <dd class="abilities">
# <span class="ability-label">Comatose</span>
# </dd>
# </dl>
# <span class="notch-bottom-center-small"></span>
# </div>
# <a class="block-link" href="/us/pokedex/komala" style="background-color: #fff; opacity: 0;" title="Komala">
# <span class="offscreen">Komala Profile</span>
# </a>
# </li>
# <li data-analytics-label="Stonjourner | " data-content-category="Featured Pokemon" data-content-download="" data-content-id="featured-item" data-content-location="" data-content-type="Slider" data-content-variation="slideCenter">
# <div class="pokedex-bg">874</div>
# ...
# </div>
# <div class="banner banner-pink">
# <h3>Return to the Sinnoh Region</h3>
# <p>A classic adventure is back with a modern update in <em>Pokémon Brilliant Diamond</em> and <em>Pokémon Shining Pearl</em>.</p>
# </div>
# </div>
# </a>
# </div>
# <div class="column-4 push-5" data-tile-position="Middle_">
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/therian-forme-tornadus-therian-forme-thundurus-and-therian-forme-landorus-will-make-their-pokemon-go-debut-in-the-season-of-legends/">
# <div class="content-block content-block-full">
# <div class="tile-image-wrapper">
# <img alt="Celebrate the Season of Legends in Pokémon GO from March 1 to June 1" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg"/>
# </div>
# <div class="banner banner-purple">
# <h3>Celebrate the Season of Legends in Pokémon GO from March 1 to June 1</h3>
# <p>Therian Forme Tornadus, Therian Forme Thundurus, and Therian Forme Landorus will make their Pokémon GO debut.</p>
# </div>
# </div>
# </a>
# <div class="content-block content-block-full hidden-mobile">
# <h2 class="section-title">What's New This Week</h2>
# </div>
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="http://pokemon.com/LegendsArceus">
# <div class="content-block content-block-full">
# <div class="tile-image-wrapper">
# <img alt="Explore the Sinnoh of the Past with Pokémon Legends: Arceus" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg"/>
# </div>
# <div class="banner banner-black">
# <h3>Explore the Sinnoh of the Past with <em>Pokémon Legends: Arceus</em></h3>
# <p>Visit the official site to get a first look at this action-infused RPG adventure.</p>
# </div>
# </div>
# </a>
# </div>
# <div class="column-4 push-9 staggered-2" data-tile-position="Right_">
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-sword-and-pokemon-shield-max-raid-battles-feature-gigantamax-corviknight-and-gigantamax-hatterene/">
# <div class="content-block content-block-full">
# <div class="tile-image-wrapper">
# <img alt="Fly High with Pokémon Sword and Pokémon Shield Max Raid Battles" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg"/>
# </div>
# <div class="banner banner-red">
# <h3>Fly High with <em>Pokémon Sword</em> and <em>Pokémon Shield</em> Max Raid Battles</h3>
# <p>Battle Fairy-type and Flying-type Pokémon in Max Raid Battles between March 1 and April 1.</p>
# </div>
# </div>
# </a>
# <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/compete-in-the-pokemon-sword-and-pokemon-shield-ranked-battles-march-2021-season/">
# <div class="content-block content-block-full">
# <div class="tile-image-wrapper">
# <img alt="March Forth in the New Ranked Battles Season" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg"/>
# </div>
# <div class="banner banner-lightblue">
# <h3>March Forth in the New Ranked Battles Season</h3>
# <p>Take on <em>Pokémon Sword</em> and <em>Pokémon Shield</em> players from around the world to earn in-game rewards during the March season.</p>
# </div>
# </div>
# </a>
# <a data-analytics-label="#need-analytics-label" href="/us/pokemon-news/">
# <div class="content-block content-block-full">
# <div class="color-block color-block-orange">
# <h2>View All News</h2>
# </div>
# <div class="banner banner-lightblue dog-ear-br">
# <p>Keep up with all the latest developments!</p>
# </div>
# </div>
# </a>
# </div>
# <div class="loader"></div>
# </section>
# <noscript>
# <div>
# <a href="/us/pokemon-news/get-a-showstopping-pikachu-in-pokemon-sword-or-pokemon-shield/">
# <h3>Get a Most Melodic Pikachu</h3>
# <p>Use this password in &lt;em&gt;Pokémon Sword&lt;/em&gt; or &lt;em&gt;Pokémon Shield&lt;/em&gt; to receive a special Pikachu that knows Sing, a move it can’t ordinarily learn.</p>
# <img alt="Get a Most Melodic Pikachu" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/distributions/pikachu/sing/pikachu-sing-169-en.jpg">
# </img></a>
# </div>
# <div>
# <a href="http://pokemon.com/DiamondPearl">
# <h3>Return to the Sinnoh Region</h3>
# <p>A classic adventure is back with a modern update in &lt;em&gt;Pokémon Brilliant Diamond&lt;/em&gt; and &lt;em&gt;Pokémon Shining Pearl&lt;/em&gt;.</p>
# <img alt="Return to the Sinnoh Region" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-brilliant-diamond-shining-pearl/announce/brilliant-diamond-shining-pearl-169-en.jpg">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/therian-forme-tornadus-therian-forme-thundurus-and-therian-forme-landorus-will-make-their-pokemon-go-debut-in-the-season-of-legends/">
# <h3>Celebrate the Season of Legends in Pokémon GO from March 1 to June 1</h3>
# <p>Therian Forme Tornadus, Therian Forme Thundurus, and Therian Forme Landorus will make their Pokémon GO debut.</p>
# <img alt="Celebrate the Season of Legends in Pokémon GO from March 1 to June 1" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg">
# </img></a>
# </div>
# <div>
# <a href="http://pokemon.com/LegendsArceus">
# <h3>Explore the Sinnoh of the Past with <em>Pokémon Legends: Arceus</em></h3>
# <p>Visit the official site to get a first look at this action-infused RPG adventure.</p>
# <img alt="Explore the Sinnoh of the Past with &lt;em&gt;Pokémon Legends: Arceus&lt;/em&gt;" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/pokemon-sword-and-pokemon-shield-max-raid-battles-feature-gigantamax-corviknight-and-gigantamax-hatterene/">
# <h3>Fly High with <em>Pokémon Sword</em> and <em>Pokémon Shield</em> Max Raid Battles</h3>
# <p>Battle Fairy-type and Flying-type Pokémon in Max Raid Battles between March 1 and April 1.</p>
# <img alt="Fly High with &lt;em&gt;Pokémon Sword&lt;/em&gt; and &lt;em&gt;Pokémon Shield&lt;/em&gt; Max Raid Battles" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg">
# </img></a>
# </div>
# <div>
# <a href="/us/pokemon-news/compete-in-the-pokemon-sword-and-pokemon-shield-ranked-battles-march-2021-season/">
# <h3>March Forth in the New Ranked Battles Season</h3>
# <p>Take on &lt;em&gt;Pokémon Sword&lt;/em&gt; and &lt;em&gt;Pokémon Shield&lt;/em&gt; players from around the world to earn in-game rewards during the March season.</p>
# <img alt="March Forth in the New Ranked Battles Season" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg">
# </img></a>
# </div>
# </noscript>
# <!-- end of container -->
# </div>
# <div class="visible-mobile" id="back-to-top">
# <span class="offscreen">Back to Top</span>
# </div>
# <div class="footer-divider">
# <span class="footer-notch"></span>
# </div>
# <footer class="global-footer">
# <div class="content-wrapper match-height-tablet">
# <div class="global-footer-links match">
# <h2><span class="offscreen">The Pokémon Company</span></h2>
# <ul>
# <li>
# <a href="/us/pokemon-news/" rel="" title="">
#           What's New
#         </a>
# </li>
# <li>
# <a href="/us/parents-guide/" rel="" title="">
#           Pokémon Parents Guide
#         </a>
# </li>
# <li>
# <a href="/us/customer-service/" rel="" title="">
#           Customer Service
#         </a>
# </li>
# <li>
# <a href="/us/about-pokemon/" rel="" title="">
#           About Our Company
#         </a>
# </li>
# <li>
# <a class="exit-link" href="https://boards.greenhouse.io/pokemoncareers" id="careers-link" rel="https://boards.greenhouse.io/pokemoncareers" target="_blank" title="External: https://boards.greenhouse.io/pokemoncareers">
#           Pokémon Careers
#         </a>
# </li>
# <li>
# <a href="/us/country-region/" rel="" title="">
#         Select a Country/Region
#         <i class="icon-us"></i>
# </a>
# </li>
# <li>
# <a class="exit-link" href="https://press.pokemon.com/" id="press-link" rel="https://press.pokemon.com/" target="_blank" title="External: https://press.pokemon.com/">
#         Pokémon Press Site
#       </a>
# </li>
# </ul>
# </div>
# <div class="global-footer-social match">
# <div class="footer-social-wrapper">
# <div class="find-us">
# <div class="find-us-box">
# <a class="facebook exit-link" href="https://www.facebook.com/pokemon" target="_blank" title="External: https://www.facebook.com/pokemon">
# <span class="offscreen">Facebook</span>
# </a>
# <a class="youtube exit-link" href="https://www.youtube.com/user/Pokemon" target="_blank" title="External: https://www.youtube.com/user/Pokemon">
# <span class="offscreen">Youtube</span>
# </a>
# <a class="twitter exit-link" href="https://www.twitter.com/pokemon" target="_blank" title="External: https://www.twitter.com/pokemon">
# <span class="offscreen">Twitter</span>
# </a>
# <a class="instagram exit-link" href="https://www.instagram.com/pokemon" target="_blank" title="External: https://www.instagram.com/pokemon">
# <span class="offscreen">Instagram</span>
# </a>
# <a class="pinterest exit-link" href="https://www.pinterest.com/pokemon" target="_blank" title="External: https://www.pinterest.com/pokemon">
# <span class="offscreen">Pinterest</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="global-footer-legal match">
# <div class="footer-legal-wrapper">
# <div id="footer--privacy">
# <a class="exit-link" href="https://caru.bbbprograms.org/seal/Confirmation/1596150491" target="_blank">
# </a>
# </div></div></div></div></footer></body></html>
# <ul>
# <li>
# <a href="/us/terms-of-use/">Terms of Use</a>
# </li>
# <li>
# <a href="/us/privacy-notice/">Privacy Notice</a>
# </li>
# <li>
# <a href="/us/cookie-page/" id="cookieLink">Cookie Page</a>
# </li>
# <li>
# <a href="/us/legal/">Legal Info</a>
# </li>
# <li>
# <a href="/us/vulnerability-disclosure-program/" id="securityLink">Security</a>
# </li>
# </ul>
#
# <span>©2021 Pokémon. TM, ®Nintendo.</span>
#
#
#
#
# <div class="popup" id="modal">
# <div class="externalLink">
# <h6>
#
#       You are about to leave a site operated by The Pokémon Company International, Inc.
#
#     </h6>
# <p>
#
# The Pokémon Company International is not responsible for the content of any linked website that is not operated by The Pokémon Company International. Please note that these websites' privacy policies and security practices may differ from The Pokémon Company International's standards.
#
#     </p>
# <div class="buttons-wrapper">
# <a class="button button-green arrow-right continueBtn" href="#">
#
#         Continue
#
#       </a>
# <a class="button button-darkgray arrow-left closeBtn" href="#">
#
#         Cancel
#
#       </a>
# </div>
# </div>
# </div>
# <div class="popup" id="pokemon-center-modal">
# <div class="externalLink centerLink">
# <h6>
#       Click Continue to visit PokemonCenter.com, our official online shop.
#     </h6>
# <h6>
#       The privacy and security policies differ.
#     </h6>
# <div class="buttons-wrapper">
# <a class="button button-green arrow-right continueBtn" href="#">
#
#         Continue
#
#       </a>
# <a class="button button-darkgray arrow-left closeBtn" href="#" target="_blank">
#
#         Cancel
#
#       </a>
# </div>
# </div>
# </div>
# <div class="popup" id="site-search-modal">
# <form class="form-analytics" id="site-search-widget" name="site-search-modal">
# <span class="search"><input autocomplete="off" id="site-search-widget-term" name="search" placeholder="Search" type="search"/></span>
# <span class="submit icon icon_search"><input id="site-search-widget-submit" type="submit" value=""/></span>
# <div id="modal-search-results"></div>
# </form>
# </div>
# <div class="popup" id="report-screen-name-success-modal">
# <h6>Report Inappropriate Screen Name</h6>
# <div class="modalBox">
# <img alt="" class="hidden-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/external_link_bumper.png"/>
# <p>
#     Pokemon.com administrators have been notified and will review the screen name for compliance with the Terms of Use.
#     </p>
# <div class="buttons-wrapper">
# <a class="button button-orange closeBtn" href="#">
#         Close
#       </a>
# </div>
# </div>
# </div>
# <div class="popup" id="report-screen-name-failure-modal">
# <h6>Report Inappropriate Screen Name</h6>
# <div class="modalBox">
# <img alt="" class="hidden-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/external_link_bumper.png"/>
# <p>
#     Your request could not be completed. Please try again. If the problem persists, please contact Customer Support.
#     </p>
# <div class="buttons-wrapper">
# <a class="button button-orange closeBtn" href="#">
#         Close
#       </a>
# </div>
# </div>
# </div>
# <div class="popupScreen" id="popupScreen"></div>
# <div class="popup" id="video-modal">
# <span class="watch-token-info"><span class="token_icon"></span><p class="token_verbal">You've been awarded <span class="token_amount">0</span> Token(s) for watching Pokémon TV!</p></span>
# <div class="video-modal-wrapper">
# <header class="video-header">
# <h4 id="episodeInfo">
# </h4>
# <!-- HEADLINE -->
# <h1 id="episodeTitle"></h1>
# </header>
# <div class="video-container">
# </div>
# <p class="hidden-text"><strong>Views: <span id="videoViews"></span></strong></p>
# <p class="legal"></p>
# <p class="video-summary">
# </p>
# <a class="closeBtn button button-orange no-arrow right" href="#"><i class="icon icon_multiply"></i> Close</a>
# </div>
# </div>
# <script type="text/javascript">
# if (typeof _satellite !== "undefined") {
#   _satellite.pageBottom();
# }
# </script>

# %%
soup.title
# Out:
# <title>The Official Pokémon Website | Pokemon.com |
#
#     Explore the World of Pokémon
#
# </title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'The Official Pokémon Website | Pokemon.com | \n  \n    Explore the World of Pokémon\n  \n'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p
# Out:
# <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>

# %%
soup.a
# Out:
# <a class="nav-toggle" href="#"><span class="icon icon_hamburger"></span></a>

# %%
soup.div
# Out:
# <div id="gus-wrapper">
# <div class="pokemon-gus-container" data-api="https://www.pokemon.com/api/gus/" data-locale="en" data-site="pcom" data-width="913px"></div>
# </div>

# %%
soup.a['class']
# Out:
# ['nav-toggle']

# %%
soup.a['href']
# Out:
# '#'

# %%
soup.div['id']
# Out:
# 'gus-wrapper'

# %% [markdown]
# #### 3. Use the `find()` method to get a result from a specific tag:

# %%
soup.find('a')
# Out:
# <a class="nav-toggle" href="#"><span class="icon icon_hamburger"></span></a>

# %%
soup.find('p')
# Out:
# <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>

# %%
soup.find('div')
# Out:
# <div id="gus-wrapper">
# <div class="pokemon-gus-container" data-api="https://www.pokemon.com/api/gus/" data-locale="en" data-site="pcom" data-width="913px"></div>
# </div>

# %%
soup.find(id="gus-wrapper")
# Out:
# <div id="gus-wrapper">
# <div class="pokemon-gus-container" data-api="https://www.pokemon.com/api/gus/" data-locale="en" data-site="pcom" data-width="913px"></div>
# </div>

# %% [markdown]
# #### 4. Use `find_all()` to get all the results of a given type:

# %%
soup.find_all('a')
# Out:
# [<a class="nav-toggle" href="#"><span class="icon icon_hamburger"></span></a>,
#  <a href="/us/pokemon-trainer-club/login">
#  <div class="avatar-icon-wrapper">
#  <img alt="View Profile" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-avatar.png"/>
#  </div>
#  </a>,
#  <a href="/us/pokemon-trainer-club/login">
#  <div class="avatar-icon-wrapper">
#  <img alt="Log In / Sign Up" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>
#  </div>
#  <div class="sign-in-text-wrapper sign-in-text-wrapper-mobile">
#                              Log In
#                          </div>
#  </a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/" target="_self">
#  <span class="fill"></span>
#  <span class="icon icon_home">
#  </span>
#  <span class="title title_home">Home</span>
#  </a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokedex/" target="_self">
#  <span class="fill"></span>
#  <span class="icon icon_pokeball">
#  </span>
#  <span class="title title_pokeball">Pokédex</span>
#  </a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-video-games/" target="_self">
#  <span class="fill"></span>
#  <span class="icon icon_joystick">
#  </span>
#  <span class="title title_joystick">Video Games &amp; Apps</span>
#  </a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/" target="_self">
#  <span class="fill"></span>
#  <span class="icon icon_cards">
#  </span>
#  <span class="title title_cards">Trading Card Game</span>
#  </a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a href="#"><span class="title">Trading Card Game</span></a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/play-online/" target="_self">Pokémon TCG Online</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-tcg/play-online/leaderboards/" target="_self">TCG Online Leaderboards</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-episodes/" target="_self">
#  <span class="fill"></span>
#  <span class="icon icon_pokemontv">
#  </span>
#  <span class="title title_pokemontv">Pokémon TV</span>
#  </a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/" target="_self">
#  <span class="fill"></span>
#  <span class="icon icon_event">
#  </span>
#  <span class="title title_event">Play! Pokémon Events</span>
#  </a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a href="#"><span class="title">Play! Pokémon Events</span></a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/" target="_self">Play! Pokémon Events</a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a href="#"><span class="title">Play! Pokémon Events</span></a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/" target="_self">Play! Pokémon Events</a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a href="#"><span class="title">Play! Pokémon Events</span></a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/find-an-event/" target="_self">Event Locator</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/play-in-a-league/" target="_self">Pokémon League</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pokemon-tournaments/" target="_self">Pokémon Championship Series</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pokemon-tournaments/earn-championship-points/" target="_self">Championship Points</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/leaderboards/" target="_self">Championship Rating and Rankings</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/pokemon-events/pre-release-tournaments/" target="_self">Prerelease Tournaments</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/" target="_self">About Play! Pokémon</a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a class="subnav-toggle" href="#"><span class="icon"></span></a>,
#  <a href="#"><span class="title">About Play! Pokémon</span></a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/play-points/" target="_self">Play! Points</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/tournaments-rules-and-resources/" target="_self">Rules &amp; Resources</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/tournaments-glossary/" target="_self">Play! Pokémon Glossary</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/video-game-glossary/" target="_self">Video Game Glossary</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/about/parents-guide/" target="_self">Parents Guide</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/organize/" target="_self">Organize Events</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/play-pokemon/leaderboards/" target="_self">Play! Pokémon Leaderboards</a>,
#  <a data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="Sidebar" data-content-variation="sidebarLeft" href="/us/pokemon-news/" target="_self">
#  <span class="fill"></span>
#  <span class="icon icon_news">
#  </span>
#  <span class="title title_news">News</span>
#  </a>,
#  <a href="https://club.pokemon.com/us/pokemon-trainer-club/login">
#  <span class="">
#  <div class="avatar-icon-wrapper">
#  <img alt="Sign In" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>
#  </div>
#  <div class="sign-in-text-wrapper">
#                                  Log In
#                              </div>
#  </span>
#  </a>,
#  <a href="/us/pokemon-trainer-club/my-profile/">
#  <span class="">
#  <div class="avatar-icon-wrapper">
#  <img alt="Profile" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-avatar.png"/>
#  </div>
#  </span>
#  </a>,
#  <a href="/us/pokemon-trainer-club/friends/">
#  <span class="icon icon_friends">
#  <span class="offscreen">Friends</span>
#  </span>
#  </a>,
#  <a href="/us/pokemon-trainer-club/play-pokemon/events/">
#  <span class="">
#  <div class="organizer-icon-wrapper">
#  <img alt="Profile" class="organizer-icon default" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-builder.png"/>
#  <img alt="Profile" class="organizer-icon ie9-hover" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-builder-ie9-hover.png"/>
#  <span class="offscreen">Profile</span>
#  </div>
#  </span>
#  </a>,
#  <a href="/us/pokemon-trainer-club/logout">
#  <span>Log Out</span>
#  </a>,
#  <a class="icon icon_search" href="">
#  <span class="offscreen"></span>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-tcg-top-deck-academy-episode-5-whimsicott-shows-heavyweight-power/">
#  <div class="content-block content-block-full content-hero">
#  <div class="content-hero-wrapper">
#  <div class="tile-image-wrapper">
#  <img alt="Top Deck Academy: Small Pokémon Can Do Big Damage, Too" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg"/>
#  </div>
#  </div>
#  <div class="banner banner-gray">
#  <h3>Top Deck Academy: Small Pokémon Can Do Big Damage, Too</h3>
#  <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-gos-march-community-day-features-fletchling/">
#  <div class="content-block content-block-half-first">
#  <div class="tile-image-wrapper">
#  <img alt="Fletchling Features in March Community Day" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg"/>
#  </div>
#  <div class="banner banner-brown">
#  <h3>Fletchling Features in March Community Day</h3>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/compete-in-the-spikemuth-cup-online-competition/">
#  <div class="content-block content-block-half">
#  <div class="tile-image-wrapper">
#  <img alt="Compete in the Spikemuth Cup" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg"/>
#  </div>
#  <div class="banner banner-black">
#  <h3>Compete in the Spikemuth Cup</h3>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/see-urshifu-tapu-koko-and-more-in-pokemon-tcg-sword-shield-battle-styles/">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="See Urshifu’s Two Sword &amp; Shield—Battle Styles Cards" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg"/>
#  </div>
#  <div class="banner banner-blue">
#  <h3>See Urshifu’s Two <em>Sword &amp; Shield—Battle Styles</em> Cards</h3>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-journeys-the-series-on-netflix-recap/">
#  <div class="content-block content-block-full">
#  <div class="banner banner-right banner-green">
#  <div class="tile-image-wrapper">
#  <img alt="Pokémon Journeys: The Series Recap" src="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png"/>
#  </div>
#  <div class="banner-wrapper">
#  <h3><em>Pokémon Journeys: The Series</em> Recap</h3>
#  </div>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/take-the-pokemon-tcg-background-pokemon-quiz/">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="Test Your Pokémon TCG: Sword &amp; Shield Series Knowledge with This Background Pokémon Quiz" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png"/>
#  </div>
#  <div class="banner banner-lightpurple">
#  <h3>Test Your Pokémon TCG: <em>Sword &amp; Shield</em> Series Knowledge with This Background Pokémon Quiz</h3>
#  </div>
#  </div>
#  </a>,
#  <a href="/us/pokemon-news/pokemon-tcg-top-deck-academy-episode-5-whimsicott-shows-heavyweight-power/">
#  <h3>Top Deck Academy: Small Pokémon Can Do Big Damage, Too</h3>
#  <p>See how the lightweight Whimsicott has what it takes to bring down the mightiest Pokémon TCG opponents.</p>
#  <img alt="Top Deck Academy: Small Pokémon Can Do Big Damage, Too" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/top-deck-academy/top-deck-academy-169.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/see-urshifu-tapu-koko-and-more-in-pokemon-tcg-sword-shield-battle-styles/">
#  <h3>See Urshifu’s Two <em>Sword &amp; Shield—Battle Styles</em> Cards</h3>
#  <p></p>
#  <img alt="See Urshifu’s Two &lt;em&gt;Sword &amp; Shield—Battle Styles&lt;/em&gt; Cards" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/swsh05/featured-cards/swsh05-featured-cards-1-169-en.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/pokemon-journeys-the-series-on-netflix-recap/">
#  <h3><em>Pokémon Journeys: The Series</em> Recap</h3>
#  <p></p>
#  <img alt="&lt;em&gt;Pokémon Journeys: The Series&lt;/em&gt; Recap" src="https://assets.pokemon.com/assets//cms2/img/watch-pokemon-tv/_tiles/season23/netflix/recap/02/season23-on-netflix-34.png">
#  </img></a>,
#  <a href="/us/pokemon-news/pokemon-gos-march-community-day-features-fletchling/">
#  <h3>Fletchling Features in March Community Day</h3>
#  <p></p>
#  <img alt="Fletchling Features in March Community Day" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03032021/pokemon-go-169.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/compete-in-the-spikemuth-cup-online-competition/">
#  <h3>Compete in the Spikemuth Cup</h3>
#  <p></p>
#  <img alt="Compete in the Spikemuth Cup" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/online-competition/spikemuth-cup/spikemuth-cup-169-en.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/take-the-pokemon-tcg-background-pokemon-quiz/">
#  <h3>Test Your Pokémon TCG: <em>Sword &amp; Shield</em> Series Knowledge with This Background Pokémon Quiz</h3>
#  <p></p>
#  <img alt="Test Your Pokémon TCG: &lt;em&gt;Sword &amp; Shield&lt;/em&gt; Series Knowledge with This Background Pokémon Quiz" src="https://assets.pokemon.com/assets//cms2/img/trading-card-game/_tiles/quiz/background/background-quiz-169.png">
#  </img></a>,
#  <a class="block-link" href="/us/pokedex/pidgey" style="background-color: #fff; opacity: 0;" title="Pidgey">
#  <span class="offscreen">Pidgey Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/rampardos" style="background-color: #fff; opacity: 0;" title="Rampardos">
#  <span class="offscreen">Rampardos Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/palkia" style="background-color: #fff; opacity: 0;" title="Palkia">
#  <span class="offscreen">Palkia Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/stoutland" style="background-color: #fff; opacity: 0;" title="Stoutland">
#  <span class="offscreen">Stoutland Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/duosion" style="background-color: #fff; opacity: 0;" title="Duosion">
#  <span class="offscreen">Duosion Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/delphox" style="background-color: #fff; opacity: 0;" title="Delphox">
#  <span class="offscreen">Delphox Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/aegislash" style="background-color: #fff; opacity: 0;" title="Aegislash">
#  <span class="offscreen">Aegislash Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/toucannon" style="background-color: #fff; opacity: 0;" title="Toucannon">
#  <span class="offscreen">Toucannon Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/komala" style="background-color: #fff; opacity: 0;" title="Komala">
#  <span class="offscreen">Komala Profile</span>
#  </a>,
#  <a class="block-link" href="/us/pokedex/stonjourner" style="background-color: #fff; opacity: 0;" title="Stonjourner">
#  <span class="offscreen">Stonjourner Profile</span>
#  </a>,
#  <a class="button button-black right" href="/us/pokedex/">Explore More Pokémon</a>,
#  <a href="/us/pokedex/pidgey">
#  <h5>Pidgey</h5>
#  <img alt="Pidgey" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//016.png">
#  </img></a>,
#  <a href="/us/pokedex/rampardos">
#  <h5>Rampardos</h5>
#  <img alt="Rampardos" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//409.png">
#  </img></a>,
#  <a href="/us/pokedex/palkia">
#  <h5>Palkia</h5>
#  <img alt="Palkia" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//484.png">
#  </img></a>,
#  <a href="/us/pokedex/stoutland">
#  <h5>Stoutland</h5>
#  <img alt="Stoutland" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//508.png">
#  </img></a>,
#  <a href="/us/pokedex/duosion">
#  <h5>Duosion</h5>
#  <img alt="Duosion" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//578.png">
#  </img></a>,
#  <a href="/us/pokedex/delphox">
#  <h5>Delphox</h5>
#  <img alt="Delphox" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//655.png">
#  </img></a>,
#  <a href="/us/pokedex/aegislash">
#  <h5>Aegislash</h5>
#  <img alt="Aegislash" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//681.png">
#  </img></a>,
#  <a href="/us/pokedex/toucannon">
#  <h5>Toucannon</h5>
#  <img alt="Toucannon" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//733.png">
#  </img></a>,
#  <a href="/us/pokedex/komala">
#  <h5>Komala</h5>
#  <img alt="Komala" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//775.png">
#  </img></a>,
#  <a href="/us/pokedex/stonjourner">
#  <h5>Stonjourner</h5>
#  <img alt="Stonjourner" src="https://assets.pokemon.com/assets/cms2/img/pokedex/full//874.png">
#  </img></a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/distributions/pikachu/sing/pikachu-sing-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/get-a-showstopping-pikachu-in-pokemon-sword-or-pokemon-shield/">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="Get a Most Melodic Pikachu" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/distributions/pikachu/sing/pikachu-sing-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/distributions/pikachu/sing/pikachu-sing-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/distributions/pikachu/sing/pikachu-sing-169-en.jpg"/>
#  </div>
#  <div class="banner banner-yellow">
#  <h3>Get a Most Melodic Pikachu</h3>
#  <p>Use this password in <em>Pokémon Sword</em> or <em>Pokémon Shield</em> to receive a special Pikachu that knows Sing, a move it can’t ordinarily learn.</p>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-brilliant-diamond-shining-pearl/announce/brilliant-diamond-shining-pearl-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="http://pokemon.com/DiamondPearl">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="Return to the Sinnoh Region" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-brilliant-diamond-shining-pearl/announce/brilliant-diamond-shining-pearl-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-brilliant-diamond-shining-pearl/announce/brilliant-diamond-shining-pearl-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-brilliant-diamond-shining-pearl/announce/brilliant-diamond-shining-pearl-169-en.jpg"/>
#  </div>
#  <div class="banner banner-pink">
#  <h3>Return to the Sinnoh Region</h3>
#  <p>A classic adventure is back with a modern update in <em>Pokémon Brilliant Diamond</em> and <em>Pokémon Shining Pearl</em>.</p>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/therian-forme-tornadus-therian-forme-thundurus-and-therian-forme-landorus-will-make-their-pokemon-go-debut-in-the-season-of-legends/">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="Celebrate the Season of Legends in Pokémon GO from March 1 to June 1" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg"/>
#  </div>
#  <div class="banner banner-purple">
#  <h3>Celebrate the Season of Legends in Pokémon GO from March 1 to June 1</h3>
#  <p>Therian Forme Tornadus, Therian Forme Thundurus, and Therian Forme Landorus will make their Pokémon GO debut.</p>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="http://pokemon.com/LegendsArceus">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="Explore the Sinnoh of the Past with Pokémon Legends: Arceus" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg"/>
#  </div>
#  <div class="banner banner-black">
#  <h3>Explore the Sinnoh of the Past with <em>Pokémon Legends: Arceus</em></h3>
#  <p>Visit the official site to get a first look at this action-infused RPG adventure.</p>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/pokemon-sword-and-pokemon-shield-max-raid-battles-feature-gigantamax-corviknight-and-gigantamax-hatterene/">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="Fly High with Pokémon Sword and Pokémon Shield Max Raid Battles" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg"/>
#  </div>
#  <div class="banner banner-red">
#  <h3>Fly High with <em>Pokémon Sword</em> and <em>Pokémon Shield</em> Max Raid Battles</h3>
#  <p>Battle Fairy-type and Flying-type Pokémon in Max Raid Battles between March 1 and April 1.</p>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" data-content-category="" data-content-download="" data-content-id="" data-content-location="" data-content-type="" data-content-variation="" href="/us/pokemon-news/compete-in-the-pokemon-sword-and-pokemon-shield-ranked-battles-march-2021-season/">
#  <div class="content-block content-block-full">
#  <div class="tile-image-wrapper">
#  <img alt="March Forth in the New Ranked Battles Season" class="breakpoint rating-image" data-maxwidth720px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" data-minwidth721px="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg"/>
#  </div>
#  <div class="banner banner-lightblue">
#  <h3>March Forth in the New Ranked Battles Season</h3>
#  <p>Take on <em>Pokémon Sword</em> and <em>Pokémon Shield</em> players from around the world to earn in-game rewards during the March season.</p>
#  </div>
#  </div>
#  </a>,
#  <a data-analytics-label="#need-analytics-label" href="/us/pokemon-news/">
#  <div class="content-block content-block-full">
#  <div class="color-block color-block-orange">
#  <h2>View All News</h2>
#  </div>
#  <div class="banner banner-lightblue dog-ear-br">
#  <p>Keep up with all the latest developments!</p>
#  </div>
#  </div>
#  </a>,
#  <a href="/us/pokemon-news/get-a-showstopping-pikachu-in-pokemon-sword-or-pokemon-shield/">
#  <h3>Get a Most Melodic Pikachu</h3>
#  <p>Use this password in &lt;em&gt;Pokémon Sword&lt;/em&gt; or &lt;em&gt;Pokémon Shield&lt;/em&gt; to receive a special Pikachu that knows Sing, a move it can’t ordinarily learn.</p>
#  <img alt="Get a Most Melodic Pikachu" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/distributions/pikachu/sing/pikachu-sing-169-en.jpg">
#  </img></a>,
#  <a href="http://pokemon.com/DiamondPearl">
#  <h3>Return to the Sinnoh Region</h3>
#  <p>A classic adventure is back with a modern update in &lt;em&gt;Pokémon Brilliant Diamond&lt;/em&gt; and &lt;em&gt;Pokémon Shining Pearl&lt;/em&gt;.</p>
#  <img alt="Return to the Sinnoh Region" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-brilliant-diamond-shining-pearl/announce/brilliant-diamond-shining-pearl-169-en.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/therian-forme-tornadus-therian-forme-thundurus-and-therian-forme-landorus-will-make-their-pokemon-go-debut-in-the-season-of-legends/">
#  <h3>Celebrate the Season of Legends in Pokémon GO from March 1 to June 1</h3>
#  <p>Therian Forme Tornadus, Therian Forme Thundurus, and Therian Forme Landorus will make their Pokémon GO debut.</p>
#  <img alt="Celebrate the Season of Legends in Pokémon GO from March 1 to June 1" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-go/03012021/pokemon-go-169.jpg">
#  </img></a>,
#  <a href="http://pokemon.com/LegendsArceus">
#  <h3>Explore the Sinnoh of the Past with <em>Pokémon Legends: Arceus</em></h3>
#  <p>Visit the official site to get a first look at this action-infused RPG adventure.</p>
#  <img alt="Explore the Sinnoh of the Past with &lt;em&gt;Pokémon Legends: Arceus&lt;/em&gt;" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-legends-arceus/announce/pokemon-legends-arceus-169-en.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/pokemon-sword-and-pokemon-shield-max-raid-battles-feature-gigantamax-corviknight-and-gigantamax-hatterene/">
#  <h3>Fly High with <em>Pokémon Sword</em> and <em>Pokémon Shield</em> Max Raid Battles</h3>
#  <p>Battle Fairy-type and Flying-type Pokémon in Max Raid Battles between March 1 and April 1.</p>
#  <img alt="Fly High with &lt;em&gt;Pokémon Sword&lt;/em&gt; and &lt;em&gt;Pokémon Shield&lt;/em&gt; Max Raid Battles" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/max-raid-battles/03012021/sword-shield-169-en.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/compete-in-the-pokemon-sword-and-pokemon-shield-ranked-battles-march-2021-season/">
#  <h3>March Forth in the New Ranked Battles Season</h3>
#  <p>Take on &lt;em&gt;Pokémon Sword&lt;/em&gt; and &lt;em&gt;Pokémon Shield&lt;/em&gt; players from around the world to earn in-game rewards during the March season.</p>
#  <img alt="March Forth in the New Ranked Battles Season" src="https://assets.pokemon.com/assets//cms2/img/video-games/_tiles/pokemon-sword-shield/ranked-battles/2021/march-ranked-battle-season-169-en.jpg">
#  </img></a>,
#  <a href="/us/pokemon-news/" rel="" title="">
#            What's New
#          </a>,
#  <a href="/us/parents-guide/" rel="" title="">
#            Pokémon Parents Guide
#          </a>,
#  <a href="/us/customer-service/" rel="" title="">
#            Customer Service
#          </a>,
#  <a href="/us/about-pokemon/" rel="" title="">
#            About Our Company
#          </a>,
#  <a class="exit-link" href="https://boards.greenhouse.io/pokemoncareers" id="careers-link" rel="https://boards.greenhouse.io/pokemoncareers" target="_blank" title="External: https://boards.greenhouse.io/pokemoncareers">
#            Pokémon Careers
#          </a>,
#  <a href="/us/country-region/" rel="" title="">
#          Select a Country/Region
#          <i class="icon-us"></i>
#  </a>,
#  <a class="exit-link" href="https://press.pokemon.com/" id="press-link" rel="https://press.pokemon.com/" target="_blank" title="External: https://press.pokemon.com/">
#          Pokémon Press Site
#        </a>,
#  <a class="facebook exit-link" href="https://www.facebook.com/pokemon" target="_blank" title="External: https://www.facebook.com/pokemon">
#  <span class="offscreen">Facebook</span>
#  </a>,
#  <a class="youtube exit-link" href="https://www.youtube.com/user/Pokemon" target="_blank" title="External: https://www.youtube.com/user/Pokemon">
#  <span class="offscreen">Youtube</span>
#  </a>,
#  <a class="twitter exit-link" href="https://www.twitter.com/pokemon" target="_blank" title="External: https://www.twitter.com/pokemon">
#  <span class="offscreen">Twitter</span>
#  </a>,
#  <a class="instagram exit-link" href="https://www.instagram.com/pokemon" target="_blank" title="External: https://www.instagram.com/pokemon">
#  <span class="offscreen">Instagram</span>
#  </a>,
#  <a class="pinterest exit-link" href="https://www.pinterest.com/pokemon" target="_blank" title="External: https://www.pinterest.com/pokemon">
#  <span class="offscreen">Pinterest</span>
#  </a>,
#  <a class="exit-link" href="https://caru.bbbprograms.org/seal/Confirmation/1596150491" target="_blank">
#  </a>,
#  <a href="/us/terms-of-use/">Terms of Use</a>,
#  <a href="/us/privacy-notice/">Privacy Notice</a>,
#  <a href="/us/cookie-page/" id="cookieLink">Cookie Page</a>,
#  <a href="/us/legal/">Legal Info</a>,
#  <a href="/us/vulnerability-disclosure-program/" id="securityLink">Security</a>,
#  <a class="button button-green arrow-right continueBtn" href="#">
#
#          Continue
#
#        </a>,
#  <a class="button button-darkgray arrow-left closeBtn" href="#">
#
#          Cancel
#
#        </a>,
#  <a class="button button-green arrow-right continueBtn" href="#">
#
#          Continue
#
#        </a>,
#  <a class="button button-darkgray arrow-left closeBtn" href="#" target="_blank">
#
#          Cancel
#
#        </a>,
#  <a class="button button-orange closeBtn" href="#">
#          Close
#        </a>,
#  <a class="button button-orange closeBtn" href="#">
#          Close
#        </a>,
#  <a class="closeBtn button button-orange no-arrow right" href="#"><i class="icon icon_multiply"></i> Close</a>]

# %%
all_links = soup.find_all('a')
all_images = soup.find_all('img')
print(len(all_links))
print(len(all_images))
# Out:
# 120
# 52

# %%
all_links[0]
# Out:
# <a class="nav-toggle" href="#"><span class="icon icon_hamburger"></span></a>

# %%
all_links[-1]
# Out:
# <a class="closeBtn button button-orange no-arrow right" href="#"><i class="icon icon_multiply"></i> Close</a>

# %%
all_images[:3]
# Out:
# [<img alt="View Profile" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-avatar.png"/>,
#  <img alt="Log In / Sign Up" class="avatar-icon avatar-icon-mobile" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>,
#  <img alt="Sign In" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>]

# %% [markdown]
# #### 5. Get the `alt` attributes from all the `<img>` elements:

# %%
for link in soup.find_all('img'):
    print(link.get('alt'))
# Out:
# View Profile
# Log In / Sign Up
# Sign In
# Profile
# Profile
# Profile
# Top Deck Academy: Small Pokémon Can Do Big Damage, Too
# Fletchling Features in March Community Day
# Compete in the Spikemuth Cup
# See Urshifu’s Two Sword & Shield—Battle Styles Cards
# Pokémon Journeys: The Series Recap
# Test Your Pokémon TCG: Sword & Shield Series Knowledge with This Background Pokémon Quiz
# Top Deck Academy: Small Pokémon Can Do Big Damage, Too
# See Urshifu’s Two <em>Sword & Shield—Battle Styles</em> Cards
# <em>Pokémon Journeys: The Series</em> Recap
# Fletchling Features in March Community Day
# Compete in the Spikemuth Cup
# Test Your Pokémon TCG: <em>Sword & Shield</em> Series Knowledge with This Background Pokémon Quiz
# Pidgey
# Rampardos
# Palkia
# Stoutland
# Duosion
# Delphox
# Aegislash
# Toucannon
# Komala
# Stonjourner
# Pidgey
# Rampardos
# Palkia
# Stoutland
# Duosion
# Delphox
# Aegislash
# Toucannon
# Komala
# Stonjourner
# Get a Most Melodic Pikachu
# Return to the Sinnoh Region
# Celebrate the Season of Legends in Pokémon GO from March 1 to June 1
# Explore the Sinnoh of the Past with Pokémon Legends: Arceus
# Fly High with Pokémon Sword and Pokémon Shield Max Raid Battles
# March Forth in the New Ranked Battles Season
# Get a Most Melodic Pikachu
# Return to the Sinnoh Region
# Celebrate the Season of Legends in Pokémon GO from March 1 to June 1
# Explore the Sinnoh of the Past with <em>Pokémon Legends: Arceus</em>
# Fly High with <em>Pokémon Sword</em> and <em>Pokémon Shield</em> Max Raid Battles
# March Forth in the New Ranked Battles Season
