# %% [markdown]
# # Web Scraping with Pandas

# %%
import pandas as pd

# %%
novelists = pd.read_html("https://en.wikipedia.org/wiki/List_of_Russian-language_novelists")
novelists
# Out:
# [                    Portrait                            Author  \
#  0                        NaN         Fyodor Abramov(1920–1983)
#  1                        NaN              M. Ageyev(1898–1973)
#  2                        NaN      Chinghiz Aitmatov(1928–2008)
#  3                        NaN           David Aizman(1869-1922)
#  4                        NaN         Sergey Aksakov(1791–1859)
#  5                        NaN        Vasily Aksyonov(1932–2009)
#  6                        NaN           Boris Akunin(born 1956)
#  7                        NaN          Mikhail Albov(1851-1911)
#  8                        NaN        Yuz Aleshkovsky(born 1929)
#  9                        NaN  Alexander Amfiteatrov(1862–1938)
#  10                       NaN        Daniil Andreyev(1906–1959)
#  11                       NaN        Leonid Andreyev(1871–1919)
#  12                       NaN          Yury Annenkov(1889–1974)
#  13                       NaN       Aleksey Apukhtin(1840–1893)
#  14                       NaN         Maria Arbatova(born 1957)
#  15                       NaN    Mikhail Artsybashev(1878–1927)
#  16  Monument in Krasnoyarsk.        Viktor Astafyev(1924–2001)
#  17                       NaN      Arkady Averchenko(1881–1925)
#
#                                          Notable works  \
#  0   The New LifeWooden HorsesTwo Winters and Three...
#  1                                  Novel with Cocaine
#  2   JamilyaThe White ShipThe Day Lasts More Than a...
#  3                                      The Countrymen
#  4   The Scarlet FlowerThe Family ChronicleYears of...
#  5   The BurnColleaguesGenerations of WinterThe Win...
#  6   Erast Fandorin seriesNicholas Fandorin seriesS...
#  7                                     On the New Road
#  8                                    The HandKangaroo
#  9                         Napoleonder The Fire Flower
#  10                                          Roza Mira
#  11  DarknessThe AbyssThe Red LaughThe Seven Who We...
#  12                                   A Tale of Trivia
#  13        From Death to LifeThe Archive of Countess D
#  14                                   My name is Woman
#  15  SaninIvan LandeBreaking PointTales of the Revo...
#  16  Queen FishSad DetectiveTo Live Your Life The C...
#  17                                           Ninochka
#
#                                           Illustration  \
#  0                  Memorial plaque in St. Petersburg.
#  1                                 First edition cover
#  2           At a book signing in St. Petersburg. 2007
#  3                                                 NaN
#  4                                Memorial to Aksakov.
#  5                                                 NaN
#  6     Akunin at the HeadRead literary festival, 2011.
#  7                                                 NaN
#  8                                                 NaN
#  9                                 Napoleon Bonaparte.
#  10  Daniil's parents Leonid Andreyev and Countess ...
#  11                                    1909 book cover
#  12                      Annenkov's 1917 self-portrait
#  13  Illustration from Apukhtin's novel From Death ...
#  14                            Maria Arbatova in 2009.
#  15     Artsybashev with the actress Yavorskaya, 1915.
#  16  Vladimir Putin speaking with Astafyev's widow....
#  17                             Drawing of Averchenko.
#
#                                         Illustration.1
#  0                                                 NaN
#  1                                                 NaN
#  2   Aitmatov (left) at the 2007 Cologne Literature...
#  3                                                 NaN
#  4                    The Aksakov Family Coat of Arms.
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8                                                 NaN
#  9                Painting of Napoleon by David, 1812.
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                        Memorial plaque in Bolkhov.
#  14                                                NaN
#  15                            Drawing of Artsybashev.
#  16                                                NaN
#  17                                 Averchenko, c1905.  ,
#      Portrait                               Author  \
#  0        NaN               Isaak Babel(1894–1940)
#  1        NaN          Grigory Baklanov(1923–2009)
#  2        NaN        Natalya Baranskaya(1908–2004)
#  3        NaN              Pavel Bazhov(1879–1950)
#  4        NaN           Dmitry Begichev(1786–1855)
#  5        NaN             Alexander Bek(1903–1972)
#  6        NaN               Andrei Bely(1880–1934)
#  7        NaN        Alexander Belyayev(1884–1942)
#  8        NaN            Nina Berberova(1901–1993)
#  9        NaN       Alexander Bestuzhev(1797–1837)
#  10       NaN             Vitaly Bianki(1894–1959)
#  11       NaN             Aleksei Bibik(1878–1976)
#  12       NaN              Andrei Bitov(1937–2018)
#  13       NaN  Nikolai Blagoveshchensky(1837–1889)
#  14       NaN           Pyotr Boborykin(1836-1921)
#  15       NaN        Alexander Bogdanov(1873–1928)
#  16       NaN        Vladimir Bogomolov(1926–2003)
#  17       NaN             Yuri Bondarev(1924-2020)
#  18       NaN            Leonid Borodin(1938–2011)
#  19       NaN            Valery Bryusov(1873–1924)
#  20       NaN                Yury Buida(born 1954)
#  21       NaN          Mikhail Bulgakov(1891–1940)
#  22       NaN              Kir Bulychev(1934–2003)
#  23       NaN                Ivan Bunin(1870–1953)
#
#                                          Notable works  \
#  0                             Red CavalryOdessa Tales
#  1   The FootholdForever NineteenSouth of the Main ...
#  2                               A Week Like Any Other
#  3                                The Malachite Casket
#  4                                 The Kholmsky Family
#  5   And Not to DieThe Story of an Inventor The New...
#  6               PetersburgKotik LetaevThe Silver Dove
#  7                                  ArielAmphibian Man
#  8   The AccompanistThe Tattered CloakThe Italics a...
#  9                                  The TestOn Bivouac
#  10                              Whose Nose is Better?
#  11                                                NaN
#  12  Pushkin HouseThe Monkey LinkLife in Windy Weat...
#  13                                    Before the Dawn
#  14                                         China Town
#  15                                           Red Star
#  16                            IvanThe Moment of Truth
#  17                       SilenceThe ShoreThe Hot Snow
#  18  PartingsThe Third TruthThe Story of a Strange ...
#  19  The Fiery AngelThe Republic of the Southern Cross
#  20  The Zero TrainThe Prussian BrideSinbad the Sailor
#  21  The White GuardThe Master and MargaritaHeart o...
#  22  Half a LifeGreat GusliarEarth and ElsewhereAli...
#  23  Dry ValleyThe VillageDark AvenuesThe Life of A...
#
#                                           Illustration  \
#  0                           Red Cavalry poster, 1919.
#  1                                                 NaN
#  2                                                 NaN
#  3                Commemorative coin featuring Bazhov.
#  4                                                 NaN
#  5                                                 NaN
#  6                             Portrait by Léon Bakst.
#  7                                Drawing by Belyayev.
#  8                             With her husband, 1925.
#  9   1823 title page from Bestuzhev's magazine Pola...
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                                                NaN
#  14                                                NaN
#  15                             A drawing of Bogdanov.
#  16                                                NaN
#  17                                                NaN
#  18                                                NaN
#  19                              A drawing of Bryusov.
#  20                                                NaN
#  21                                                NaN
#  22                                                NaN
#  23              Soviet Nobel Laureates in Literature.
#
#                                         Illustration.1
#  0                           Red Cavalry poster, 1920.
#  1                                                 NaN
#  2                                                 NaN
#  3                                Bazhov in his youth.
#  4                                                 NaN
#  5                                                 NaN
#  6   Plaque at Bely's birth house on Arbat Street i...
#  7                            Another of his drawings.
#  8                                                 NaN
#  9                          An engraving of Bestuzhev.
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                                                NaN
#  14                                                NaN
#  15                                                NaN
#  16                                                NaN
#  17                                                NaN
#  18                                                NaN
#  19                An Armenian stamp featuring Bryusov
#  20                                                NaN
#  21                   Soviet stamp featuring Behemoth.
#  22                                                NaN
#  23                                                NaN  ,
#     Portrait                            Author  \
#  0       NaN       Aleksey Chapygin(1870–1937)
#  1       NaN       Sergei Charchoun(1888–1975)
#  2       NaN        Lidia Charskaya(1875–1938)
#  3       NaN      Alexander Chekhov(1855–1913)
#  4       NaN          Anton Chekhov(1860–1904)
#  5       NaN  Nikolay Chernyshevsky(1828–1889)
#  6       NaN        Evgeny Chirikov(1864–1932)
#  7       NaN      Lydia Chukovskaya(1907–1996)
#  8       NaN         Georgy Chulkov(1879–1939)
#
#                                       Notable works  \
#  0                                     Stepan Razin
#  1                                       Dolgolikov
#  2                               Princess Dzhavakha
#  3                                              NaN
#  4       The Lady with the DogThe BetThe Black Monk
#  5                              What Is to Be Done?
#  6  The MagicianStrained RelationsMarka of the Pits
#  7                                   Sofia Petrovna
#  8                                              NaN
#
#                                    Illustration  \
#  0          Stepan Razin, picture by Kustodiev.
#  1                                          NaN
#  2                             Charskaya, c1910
#  3                          The Chekhov family.
#  4    Title page from Collected Works Volume 1.
#  5            Title page of What Is to Be Done?
#  6                           At his desk, 1904.
#  7                                          NaN
#  8  Chulkov (left), with fellow Soviet writers.
#
#                                    Illustration.1
#  0                                            NaN
#  1                                            NaN
#  2                                            NaN
#  3               Alexander's son Michael Chekhov.
#  4  An example from one of Chekhov's manuscripts.
#  5                                            NaN
#  6                       Portrait by Repin, 1906.
#  7                                            NaN
#  8                                            NaN  ,
#      Portrait                           Author  \
#  0        NaN           Yuli Daniel(1925–1988)
#  1        NaN    Grigory Danilevsky(1829–1890)
#  2        NaN  Grigoriy Demidovtsev(born 1960)
#  3        NaN   Valentina Dmitryeva(1859–1947)
#  4        NaN       Leonid Dobychin(1894-1936)
#  5        NaN       Yury Dombrovsky(1909–1978)
#  6        NaN      Vlas Doroshevich(1864–1922)
#  7        NaN  Lyubov Dostoyevskaya(1869–1926)
#  8        NaN    Fyodor Dostoyevsky(1821–1881)
#  9        NaN   Mikhail Dostoyevsky(1820–1864)
#  10       NaN       Sergei Dovlatov(1941–1990)
#  11       NaN   Alexander Druzhinin(1824–1864)
#  12       NaN    Vladimir Dudintsev(1918–1998)
#
#                                          Notable works  \
#  0                             This is Moscow Speaking
#  1             Moscow in FlamesThe Princess Tarakanova
#  2                                                 NaN
#  3                       Hveska, The Doctor's Watchman
#  4                   The Town of NEncounters with Lise
#  5   The Faculty of Useless KnowledgeThe Keeper of ...
#  6                     Legends and Stories of the East
#  7                                        The Emigrant
#  8   Notes from UndergroundCrime and PunishmentThe ...
#  9                                                 NaN
#  10                                  The ZoneAffiliate
#  11          Polinka SaksThe Story of Aleksei Dmitrich
#  12  White GarmentsA New Year's TaleNot by Bread Alone
#
#                                           Illustration  \
#  0                                                 NaN
#  1                                   Moscow in Flames.
#  2   Certificate of membership in the Union of Russ...
#  3                                   Dmitryeva, c1890.
#  4                                 First edition cover
#  5                                                 NaN
#  6                                 Doroshevich c.1910.
#  7   Anna Dostoyevskaya (wife of Fyodor Dostoyevsky...
#  8   Raskolnikov and Marmeladov from Crime and Puni...
#  9   Vremya (Time), the paper published by Fyodor a...
#  10                                                NaN
#  11  Druzhinin (2nd from right), with his fellow wr...
#  12                                                NaN
#
#                                         Illustration.1
#  0                                                 NaN
#  1        Princess Tarakanova by Konstantin Flavitsky.
#  2                                Demidovtsev in 2007.
#  3                                    Dmitryeva, 1895.
#  4                                                 NaN
#  5                                                 NaN
#  6                                                 NaN
#  7                                 Anna Dostoyevskaya.
#  8   Dostoyevsky's notes for chapter 5 of The Broth...
#  9                                     Portrait, 1870.
#  10                                                NaN
#  11                                 Druzhinin in 1856.
#  12                                                NaN  ,
#     Portrait                         Author  \
#  0       NaN      Ilya Ehrenburg(1891–1967)
#  1       NaN  Sergey Elpatyevsky(1854–1933)
#  2       NaN          Asar Eppel(1935–2012)
#  3       NaN     Victor Erofeyev(born 1947)
#  4       NaN     Alexander Ertel(1855–1908)
#  5       NaN   Mikhail Evstafiev(born 1963)
#
#                                    Notable works  Illustration  \
#  0  The ThawThe SpringThe StormThe Fall of Paris           NaN
#  1                     Pity Me!The Homeless Ones           NaN
#  2        The Grassy StreetRed Caviar Sandwiches           NaN
#  3              Russian BeautyLife with an Idiot           NaN
#  4                The SpecialistA Greedy Peasant  Ertel, c1890
#  5                         Two Steps from Heaven           NaN
#
#          Illustration.1
#  0  Photo of Ehrenburg.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN  ,
#     Portrait                        Author  \
#  0       NaN  Alexander Fadeyev(1901–1956)
#  1       NaN   Konstantin Fedin(1892–1977)
#  2       NaN         Olga Forsh(1873–1961)
#  3       NaN    Dmitry Furmanov(1891–1926)
#
#                                         Notable works  \
#  0                            The RoutThe Young Guard
#  1  Early JoysThe ConflagrationCities and YearsNo ...
#  2               Palace and PrisonPioneers of Freedom
#  3                                           Chapayev
#
#                      Illustration                           Illustration.1
#  0                            NaN          Soviet stamp featuring Fadeyev.
#  1  Soviet stamp featuring Fedin.                                      NaN
#  2                            NaN                                      NaN
#  3      Photo of Vasily Chapayev.  Soviet stamp featuring Vasily Chapayev.  ,
#      Portrait                                 Author  \
#  0        NaN               Arkady Gaidar(1904–1941)
#  1        NaN  Nikolai Garin-Mikhailovsky(1852–1906)
#  2        NaN            Vsevolod Garshin(1855–1888)
#  3        NaN              Gaito Gazdanov(1903–1971)
#  4        NaN                 Yuri German(1910-1967)
#  5        NaN            Anatoly Gladilin(1935–2018)
#  6        NaN              Fyodor Gladkov(1883–1958)
#  7        NaN           Dmitry Glukhovsky(born 1979)
#  8        NaN               Pyotr Gnedich(1855-1925)
#  9        NaN               Nikolai Gogol(1809–1852)
#  10       NaN              Ivan Goncharov(1812–1891)
#  11       NaN                 Maxim Gorky(1868–1936)
#  12       NaN              Nina Gorlanova(born 1947)
#  13       NaN               Daniil Granin(1919–2017)
#  14       NaN          Dmitry Grigorovich(1822–1900)
#  15       NaN              Alexander Grin(1880–1932)
#  16       NaN        Isabella Grinevskaya(1864–1944)
#  17       NaN             Vasily Grossman(1905–1964)
#  18       NaN                  Elena Guro(1887-1913)
#  19       NaN                Andrei Gusev(born 1952)
#  20       NaN    Sergey Gusev-Orenburgsky(1867–1963)
#
#                                          Notable works  \
#  0          Chuk and GekThe Blue CupTimur and his Gang
#  1                                  Practical Training
#  2                             Four DaysThe Red Flower
#  3   An Evening with ClaireNight RoadsThe Spectre o...
#  4                     Ivan LapshinThe Cause You Serve
#  5                                    Moscow Racetrack
#  6                                CementRestless Youth
#  7                                          Metro 2033
#  8                            The Burden of this World
#  9            DikankaTaras BulbaThe OvercoatDead Souls
#  10                 A Common StoryOblomovThe Precipice
#  11  MotherThrough RussiaThe Artamonov BusinessThe ...
#  12                                                NaN
#  13                       Into the StormThose Who Seek
#  14                                      The Fishermen
#  15               Scarlet SailsThe Seeker of Adventure
#  16                                                NaN
#  17               The RoadLife and FateForever Flowing
#  18  Autumnal DreamThe Hurdy-GurdyThe Little Camels...
#  19  With Chronos' Permit On the Edge of Magellanic...
#  20    The Land of the FathersThe Land of the Children
#
#                                           Illustration  \
#  0                      Soviet stamp featuring Gaidar.
#  1                      Portrait by Israel Pass, 1905.
#  2                                      The Red Flower
#  3                              An Evening with Claire
#  4                                                 NaN
#  5                           Gladilin in Moscow, 2011.
#  6                                                 NaN
#  7                                                 NaN
#  8                                                 NaN
#  9   Title page of the first edition of Dead Souls,...
#  10                                           Oblomov.
#  11                                  With Leo Tolstoy.
#  12                                                NaN
#  13                        With Dmitry Medvedev, 2009.
#  14           Self-portrait of Grigorovich in his 20s.
#  15    The Scarlet Sails celebration in St Petersburg.
#  16                                                NaN
#  17                        Memorial plaque in Donetsk.
#  18  Guro's portrait of her husband Mikhail Matyushin.
#  19                      Andrei Gusev in Moscow, 2009.
#  20                                                NaN
#
#                                Illustration.1
#  0                                        NaN
#  1   Bas-relief dedication at the Laspi Pass.
#  2                    Photo of Garshin, 1877.
#  3                     Gaito Gazdanov in 1934
#  4                                        NaN
#  5                                        NaN
#  6                                        NaN
#  7                                        NaN
#  8                                        NaN
#  9                  Nozdryov from Dead Souls.
#  10                                       NaN
#  11                       With Anton Chekhov.
#  12                                       NaN
#  13                                       NaN
#  14                     Portrait by Kramskoi.
#  15                From the 2010 celebration.
#  16                                       NaN
#  17                                       NaN
#  18                        Elena and Mikhail.
#  19                                       NaN
#  20                                       NaN  ,
#     Portrait                       Author     Notable works  \
#  0       NaN  Alexander Herzen(1812–1870)  Who is to Blame?
#
#                    Illustration  Illustration.1
#  0  Statue of Herzen in Moscow.             NaN  ,
#     Portrait                                           Author  \
#  0       NaN  Ilf and PetrovIlf (1897–1937)Petrov (1903–1942)
#  1       NaN                        Fazil Iskander(1929–2016)
#  2       NaN                         Alexei Ivanov(born 1969)
#  3       NaN                       Vsevolod Ivanov(1895–1963)
#
#                                         Notable works  \
#  0            The Twelve ChairsThe Little Golden Calf
#  1  Chik and His FriendsSandro of ChegemThe Gospel...
#  2                                                NaN
#  3                                 FertilityThe Child
#
#                                         Illustration  \
#  0             The Twelve Chairs Monument in Odessa.
#  1  Iskander with Russian President Dmitry Medvedev.
#  2                                               NaN
#  3                                               NaN
#
#                                  Illustration.1
#  0  Another view of the Twelve Chairs monument.
#  1           Abkhazian coin featuring Iskander.
#  2                                          NaN
#  3                                          NaN  ,
#      Portrait                                     Author  \
#  0        NaN                Nikolay Karamzin(1766–1826)
#  1        NaN                 Nikolay Karazin(1842–1908)
#  2        NaN  Nikolay Karonin-Petropavlovsky(1853–1892)
#  3        NaN                 Vladimir Karpov(1922–2010)
#  4        NaN                               Anna Kashina
#  5        NaN                     Ivan Kataev(1902-1937)
#  6        NaN                 Valentin Kataev(1897–1986)
#  7        NaN                Veniamin Kaverin(1902–1989)
#  8        NaN             Emmanuil Kazakevich(1913–1962)
#  9        NaN                    Yury Kazakov(1927–1982)
#  10       NaN                     Yuri Khanon(born 1965)
#  11       NaN                   Daniil Kharms(1905–1942)
#  12       NaN        Nadezhda Khvoshchinskaya(1824–1889)
#  13       NaN                 Marusya Klimova(born 1961)
#  14       NaN               Vsevolod Kochetov(1912-1973)
#  15       NaN                    Ivan Kokorev(1825–1853)
#  16       NaN             Alexandra Kollontai(1872–1952)
#  17       NaN              Vladimir Korolenko(1853–1921)
#  18       NaN              Sofia Kovalevskaya(1859–1891)
#  19       NaN               Vadim Kozhevnikov(1909–1984)
#  20       NaN           Nadezhda Kozhevnikova(born 1949)
#  21       NaN                Eugene Kozlovsky(born 1946)
#  22       NaN             Vsevolod Krestovsky(1840-1895)
#  23       NaN        Sigizmund Krzhizhanovsky(1887–1950)
#  24       NaN            Anatoly Kudryavitsky(born 1954)
#  25       NaN                Aleksandr Kuprin(1870–1938)
#  26       NaN                   Andrey Kurkov(born 1961)
#  27       NaN                Ivan Kushchevsky(1847–1876)
#  28       NaN                 Mikhail Kuzmin (1872–1936)
#  29       NaN               Anatoly Kuznetsov(1929-1979)
#
#                                          Notable works  \
#  0                                           Poor Liza
#  1              The Two-Legged WolfFrom North to South
#  2                                         First Storm
#  3                                       The Commander
#  4                            In the Name of the Queen
#  5                                 The WifeImmortality
#  6   Time Forward!The EmbezzlersA White Sail Gleams...
#  7         Open BookThe Two CaptainsThe Unknown Artist
#  8                      Star: A StoryThe Blue Notebook
#  9                           Going To TownAdam and Eve
#  10  Skryabin As a FaceAntedate MemoriesAlphonse, w...
#  11                                      The Old Woman
#  12                           The Boarding School Girl
#  13                                                NaN
#  14           The Zhurbin FamilyWhat Do You Want Then?
#  15                                                NaN
#  16            Red LoveA Great LoveLove of Worker Bees
#  17         Bad CompanyMakar's DreamThe Blind Musician
#  18                                      Nihilist Girl
#  19                                   Shield and Sword
#  20                      Attorney Alexandra Tikhonovna
#  21                                                NaN
#  22                                Knights of Industry
#  23                                        Quadraturin
#  24                                                NaN
#  25       The DuelYama: The PitThe Bracelet of Garnets
#  26                  Death and the PenguinPenguin Lost
#  27                                    Nikolai Negorev
#  28                                              Wings
#  29                                           Babi Yar
#
#                                         Illustration  \
#  0   "Poor Liza", painting by Orest Kiprensky, 1827.
#  1                   From North to South book cover.
#  2                                               NaN
#  3                                               NaN
#  4                                               NaN
#  5                                               NaN
#  6                                               NaN
#  7                                               NaN
#  8                                               NaN
#  9                                               NaN
#  10                  Erik Satie, "Antedate Memories"
#  11         Graffiti of Kharms on a wall in Kharkiv.
#  12                              Photograph, c1880s.
#  13                                 Klimova in 2006.
#  14                                              NaN
#  15                                              NaN
#  16                Soviet stamp featuring Kollontai.
#  17                                              NaN
#  18                            Bust of Kovalevskaya.
#  19                                              NaN
#  20                                              NaN
#  21                                              NaN
#  22                               Krestovsky, c1870.
#  23                                              NaN
#  24                                              NaN
#  25                      A cartoon featuring Kuprin.
#  26                                              NaN
#  27                         Portrait of Kushchevsky.
#  28   Portrait of Kuzmin by Alexander Golovin, 1910.
#  29                                              NaN
#
#                          Illustration.1
#  0            Stamp featuring Karamzin.
#  1                                  NaN
#  2                                  NaN
#  3                                  NaN
#  4                                  NaN
#  5                                  NaN
#  6                                  NaN
#  7                                  NaN
#  8                                  NaN
#  9                                  NaN
#  10          “Alphonse, who didn't was"
#  11  Caricature of Kharms by Antonovsky
#  12                   Engraving c1860s.
#  13                                 NaN
#  14                                 NaN
#  15                                 NaN
#  16             Kollontai in her youth.
#  17   The Korolenko Library in Kharkiv.
#  18                 Commemorative coin.
#  19                                 NaN
#  20                                 NaN
#  21                                 NaN
#  22                                 NaN
#  23                                 NaN
#  24                                 NaN
#  25                    Photo of Kuprin.
#  26                                 NaN
#  27                                 NaN
#  28                    Photo of Kuzmin.
#  29                                 NaN  ,
#      Portrait                        Author  \
#  0        NaN        Lazar Lagin(1903–1979)
#  1        NaN     Yulia Latynina(born 1966)
#  2        NaN    Boris Lavrenyov(1891–1953)
#  3        NaN  Ivan Lazhechnikov(1792–1869)
#  4        NaN      Leonid Leonov(1899–1995)
#  5        NaN  Mikhail Lermontov(1814–1841)
#  6        NaN     Nikolai Leskov(1831–1895)
#  7        NaN  Alexander Levitov(1835–1877)
#  8        NaN     Nikolay Leykin(1841–1906)
#  9        NaN  Vladimir Lichutin(born 1940)
#  10       NaN     Eduard Limonov(1943-2020)
#  11       NaN   Dmitri Lipskerov(born 1964)
#  12       NaN  Sergey Lukyanenko(born 1968)
#  13       NaN          Lev Lunts(1901–1924)
#
#                                          Notable works  \
#  0                             The Old Genie Hottabych
#  1                                         The Insider
#  2   The Forty-FirstThe Heavenly CapSuch a Simple T...
#  3                                         The Heretic
#  4         The BadgersSoviet RiverThe ThiefThe Pyramid
#  5                                  A Hero of Our Time
#  6   LeftyThe Sealed AngelThe Enchanted WandererLad...
#  7                             Leatherhide the Cobbler
#  8                                     Our Folk Abroad
#  9                                                 NaN
#  10  It's Me, EddieHis Butler's StoryMemoir of a Ru...
#  11                                                NaN
#  12       Night WatchDay WatchTwilight WatchLast Watch
#  13                                        Native Land
#
#                                           Illustration  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                           Portrait of Lazhechnikov.
#  4                                                 NaN
#  5   Title page from the first edition of A Hero of...
#  6                                                 NaN
#  7                                    Levitov, c1860s.
#  8                                    Photo of Leykin.
#  9                                                 NaN
#  10                      At a book presentation, 2008.
#  11                                                NaN
#  12                                       Photo, 2001.
#  13                                                NaN
#
#                                         Illustration.1
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5   Pechorin's Duel from A Hero of Our Time. Pictu...
#  6                                  Drawing of Leskov.
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10  With Garry Kasparov at the Dissenters March in...
#  11                                                NaN
#  12                                                NaN
#  13                                                NaN  ,
#      Portrait                            Author  \
#  0        NaN        Grigori Machtet(1852–1901)
#  1        NaN       Vladimir Makanin(1937–2017)
#  2        NaN  Dmitry Mamin-Sibiryak(1852–1912)
#  3        NaN      Anatoly Marienhof(1897–1962)
#  4        NaN     Alexandra Marinina(born 1957)
#  5        NaN     Boleslav Markevich(1822–1884)
#  6        NaN   Vladilen Mashkovtsev(1929–1997)
#  7        NaN         Pavel Melnikov(1818–1883)
#  8        NaN    Dmitry Merezhkovsky(1865–1941)
#  9        NaN      Daniil Mordovtsev(1830-1905)
#  10       NaN         Viktor Muyzhel(1880-1924)
#  11       NaN         Viktor Muravin(born 1929)
#
#                                          Notable works  \
#  0                                                 NaN
#  1                   Baize-Covered Table With Decanter
#  2   Verotchka's TalesA Gold NuggetThe Privalov For...
#  3                                              Cynics
#  4                                                 NaN
#  5                                   The Turning Point
#  6                                                 NaN
#  7                                                 NaN
#  8                     Christ and Antichrist (trilogy)
#  9                             The Tsar and the Hetman
#  10                                           The Year
#  11                       The Diary of Vikenty Angarov
#
#                                           Illustration  \
#  0                                                 NaN
#  1                                                 NaN
#  2                         Cover of Verotchka's Tales.
#  3                 With the poet Sergei Yesenin, 1915.
#  4                                                 NaN
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8   Merezhkovsky (right), with his wife Zinaida Gi...
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#
#                        Illustration.1
#  0                                NaN
#  1                                NaN
#  2   Title page of Verotchka's Tales.
#  3                                NaN
#  4                                NaN
#  5                                NaN
#  6                                NaN
#  7                                NaN
#  8           Portrait by Repin, 1900.
#  9                                NaN
#  10                               NaN
#  11                               NaN  ,
#      Portrait                                  Author  \
#  0        NaN             Vladimir Nabokov(1899–1977)
#  1        NaN                 Yuri Nagibin(1920–1994)
#  2        NaN              Vasily Narezhny(1780–1825)
#  3        NaN               Nikolay Naumov(1838-1901)
#  4        NaN              Andrei Navrozov(born 1956)
#  5        NaN              Viktor Nekrasov(1911–1987)
#  6        NaN  Vasily Nemirovich-Danchenko(1845-1936)
#  7        NaN            Alexander Neverov(1886–1923)
#  8        NaN          Friedrich Neznansky(1932–2013)
#  9        NaN                Nikolay Nosov(1908–1976)
#  10       NaN        Alexey Novikov-Priboy(1877-1944)
#
#                             Notable works                       Illustration  \
#  0          MaryThe DefenseThe GiftLolita                                NaN
#  1                 The PipeArise and Walk                                NaN
#  2                     A Russian Gil Blas                                NaN
#  3              Strength Breaks the Straw                                NaN
#  4                                    NaN                                NaN
#  5   Front-line StalingradKira Georgievna                                NaN
#  6                Peasant Tales of Russia                                NaN
#  7                          City of Bread                Drawing of Neverov.
#  8                 Red SquareNight Wolves                                NaN
#  9                               Neznaika  Russian stamp featuring Neznaika.
#  10    TsushimaThe CaptainThe Sea Beckons                                NaN
#
#                    Illustration.1
#  0   Nabokov's first publication.
#  1                            NaN
#  2                            NaN
#  3                            NaN
#  4                            NaN
#  5                            NaN
#  6                            NaN
#  7                            NaN
#  8                            NaN
#  9                            NaN
#  10                           NaN  ,
#     Portrait                        Author  \
#  0       NaN  Vladimir Obruchev(1863–1956)
#  1       NaN      Olga Obukhova(born 1941)
#  2       NaN  Vladimir Odoevsky(1803–1869)
#  3       NaN    Bulat Okudzhava(1924–1997)
#  4       NaN        Yury Olesha(1899–1960)
#  5       NaN  Nikolai Ostrovsky(1904–1936)
#  6       NaN    Mikhail Osorgin(1878-1942)
#  7       NaN  Valentin Ovechkin(1904-1968)
#
#                                         Notable works  \
#  0                              PlutoniaSannikov Land
#  1                                                NaN
#  2  Two PrincessesThe Living CorpseThe Year 4338: ...
#  3  A Taste of LibertyGood-bye, Schoolboy!The Art ...
#  4                    EnvyThree Fat MenThe Cherry Pit
#  5        Born of the StormHow the Steel Was Tempered
#  6                      Quiet StreetMy Sister's Story
#  7                           Greetings from the Front
#
#                                          Illustration  \
#  0                                                NaN
#  1                                                NaN
#  2  Odoevsky's dedication in a book he presented t...
#  3                                                NaN
#  4                                                NaN
#  5                         Stamp featuring Ostrovsky.
#  6                                                NaN
#  7                                                NaN
#
#                                        Illustration.1
#  0                                                NaN
#  1                                                NaN
#  2  Odoevsky (at back), with the composers Mily Ba...
#  3                         Stamp featuring Okudzhava.
#  4                                                NaN
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN  ,
#      Portrait                              Author  \
#  0        NaN             Marina Palei(born 1955)
#  1        NaN              Ivan Panaev(1812-1862)
#  2        NaN          Avdotya Panaeva(1820-1893)
#  3        NaN              Vera Panova(1905–1973)
#  4        NaN          Boris Pasternak(1890–1960)
#  5        NaN    Konstantin Paustovsky(1892–1968)
#  6        NaN           Pyotr Pavlenko(1899-1951)
#  7        NaN              Oleg Pavlov(1970-2018)
#  8        NaN         Karolina Pavlova(1807–1893)
#  9        NaN           Victor Pelevin(born 1962)
#  10       NaN  Lyudmila Petrushevskaya(born 1938)
#  11       NaN           Valentin Pikul(1928–1990)
#  12       NaN            Boris Pilnyak(1894–1938)
#  13       NaN         Aleksey Pisemsky(1821–1881)
#  14       NaN          Andrei Platonov(1899–1951)
#  15       NaN            Boris Polevoy(1908–1981)
#  16       NaN      Nikolay Pomyalovsky(1835–1863)
#  17       NaN         Ignaty Potapenko(1856–1929)
#  18       NaN            Dmitri Prigov(1940–2007)
#  19       NaN          Zakhar Prilepin(born 1975)
#  20       NaN      Alexander Prokhanov(born 1938)
#  21       NaN        Alexander Pushkin(1799–1837)
#
#                                          Notable works  \
#  0                                          Rendezvous
#  1                              Lions in the Provinces
#  2                                       A Woman's Lot
#  3      SeryozhaLooking AheadThe TrainSpan of the Year
#  4               Doctor ZhivagoThe Childhood of Luvers
#  5                     A Tale of Life (6 novel series)
#  6                HappinessSteppe SunlightThe Lost Son
#  7                                                 NaN
#  8                                       A Double Life
#  9                                             Omon Ra
#  10                                      Immortal Love
#  11                                                NaN
#  12  The Naked YearThe Death of the Army CommanderT...
#  13  NinaThe SimpletonOne Thousand SoulsAn Old Man'...
#  14                   ChevengurDzhanThe Foundation Pit
#  15  He Came BackWe Are Soviet PeopleThe Story of a...
#  16                                  Seminary Sketches
#  17             A Russian PriestThe General's Daughter
#  18                                     Live in Moskow
#  19                                                NaN
#  20                              Empire's Last Soldier
#  21          The Queen of SpadesThe Captain's Daughter
#
#                                           Illustration  \
#  0                                  Palei in Komarovo.
#  1                         Portrait by Levitsky, 1856.
#  2                                                 NaN
#  3                Plaque for Panova in St. Petersburg.
#  4               Soviet Nobel Laureates in Literature.
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8                               A drawing of Pavlova.
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                      Portrait of Pisemsky, c.1860.
#  14                                                NaN
#  15                                                NaN
#  16                       An engraving of Pomyalovsky.
#  17  Potapenko (right), with Chekhov and Mamin-Sibi...
#  18                                                NaN
#  19                                                NaN
#  20                                                NaN
#  21  The first page from the serialized version of ...
#
#                                         Illustration.1
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4   Memorial plaque at Pasternak's birthplace in M...
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                             Engraving of Pisemsky.
#  14                                                NaN
#  15                                                NaN
#  16                                                NaN
#  17                                                NaN
#  18                                                NaN
#  19                                                NaN
#  20                                                NaN
#  21                                                NaN  ,
#      Portrait                           Author  \
#  0        NaN  Alexander Radishchev(1749–1802)
#  1        NaN     Valentin Rasputin(1937–2015)
#  2        NaN       Aleksey Remizov(1877–1957)
#  3        NaN    Fyodor Reshetnikov(1841–1871)
#  4        NaN   Panteleimon Romanov(1884-1938)
#  5        NaN      Mikhail Roshchin(1933-2010)
#  6        NaN           Dina Rubina(born 1953)
#  7        NaN       Anatoly Rybakov(1911–1998)
#  8        NaN      Vladimir Rybakov(1947-2018)
#  9        NaN    Vyacheslav Rybakov(born 1954)
#  10       NaN        Maria Rybakova(born 1973)
#
#                                          Notable works  \
#  0               Journey from St. Petersburg to Moscow
#  1                  Money for MariaFarewell to Matyora
#  2                   The ClockThe Indefatigable Cymbal
#  3                                    The Podlipnayans
#  4   Three Pairs of Silk StockingsWithout Bird-Cher...
#  5   First LoveTwenty Minutes or SoThe Devil's Whee...
#  6                                      The Blackthorn
#  7             Children of the ArbatFearDust and Ashes
#  8              CreatureThe BrandThe BurdenThe Afghans
#  9                              ArtistThe Trial Sphere
#  10                                                NaN
#
#                                           Illustration  Illustration.1
#  0            Title page from the first edition, 1790.             NaN
#  1   Rasputin receiving an award from Russian Prime...             NaN
#  2                                                 NaN             NaN
#  3                             Drawing of Reshetnikov.             NaN
#  4                                                 NaN             NaN
#  5                                                 NaN             NaN
#  6                                  Dina Rubina, 2007.             NaN
#  7                                                 NaN             NaN
#  8                                                 NaN             NaN
#  9                                                 NaN             NaN
#  10                                                NaN             NaN  ,
#              Portrait                                             Author  \
#  0                NaN                          Irina Saburova(1907-1979)
#  1                NaN                         German Sadulaev(born 1973)
#  2                NaN                              Ilya Salov(1834–1902)
# ...
#  4                                  Religious leaders
#  5                                       Sportspeople
#
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vtePeople from Russia.1  \
#  0  862–1547  1547–1721  1721–1917  1917–1922  192...
#  1  Field marshals Soviet marshals Admirals Aviato...
#  2  Aerospace engineers Astronomers and astrophysi...
#  3  Architects Ballet dancers Composers Opera sing...
#  4  Metropolitans and Patriarchs Saints (until 15t...
#  5                                      Chess players
#
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vtePeople from Russia.2
#  0                                                NaN
#  1                                                NaN
#  2                                                NaN
#  3                                                NaN
#  4                                                NaN
#  5                                                NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ]

# %% [markdown]
# It returns a list with all the tables from the site converted into DataFrames.

# %%
print(type(novelists))
print(type(novelists[0]))
print(type(novelists[-1]))
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
novelists[0].sample(3)
# Out:
#    Portrait                      Author  \
# 14      NaN   Maria Arbatova(born 1957)
# 10      NaN  Daniil Andreyev(1906–1959)
# 11      NaN  Leonid Andreyev(1871–1919)
#
#                                         Notable works  \
# 14                                   My name is Woman
# 10                                          Roza Mira
# 11  DarknessThe AbyssThe Red LaughThe Seven Who We...
#
#                                          Illustration Illustration.1
# 14                            Maria Arbatova in 2009.            NaN
# 10  Daniil's parents Leonid Andreyev and Countess ...            NaN
# 11                                    1909 book cover            NaN

# %%
novelists[21].sample(3)
# Out:
#    Portrait                     Author        Notable works Illustration  \
# 4       NaN  Ilia Zdanevich(1894–1975)                  NaN          NaN
# 7       NaN   Boris Zhitkov(1882–1938)        Viktor Vavich          NaN
# 9       NaN    Zinovy Zinik(born 1945)  The Mushroom-Picker          NaN
#
#   Illustration.1
# 4            NaN
# 7            NaN
# 9            NaN

# %%
novelists[0].loc[0]
# Out:
# Portrait                                                        NaN
# Author                                    Fyodor Abramov(1920–1983)
# Notable works     The New LifeWooden HorsesTwo Winters and Three...
# Illustration                     Memorial plaque in St. Petersburg.
# Illustration.1                                                  NaN
# Name: 0, dtype: object

# %%
novelists[21].loc[0]
# Out:
# Portrait                                  NaN
# Author            Mikhail Zagoskin(1789–1852)
# Notable works        Tales of Three Centuries
# Illustration           Engraving of Zagoskin.
# Illustration.1                            NaN
# Name: 0, dtype: object

# %%
novelists[0].loc[0,'Author']
# Out:
# 'Fyodor Abramov(1920–1983)'

# %%
novelists[21].loc[0,'Author']
# Out:
# 'Mikhail Zagoskin(1789–1852)'

# %% [markdown]
# Get the Birthyear in a different column:

# %%
novelists = pd.concat(novelists[0:22], axis=0)\
        .drop(columns=['Portrait', 'Illustration','Illustration.1'])\
        .reset_index(drop=True)

novelists
# Out:
#                                  Author  \
# 0             Fyodor Abramov(1920–1983)
# 1                  M. Ageyev(1898–1973)
# 2          Chinghiz Aitmatov(1928–2008)
# 3               David Aizman(1869-1922)
# 4             Sergey Aksakov(1791–1859)
# ..                                  ...
# 300            Maria Zhukova(1804–1855)
# 301             Zinovy Zinik(born 1945)
# 302  Lydia Zinovieva-Annibal(1866–1907)
# 303     Nikolay Zlatovratsky(1845–1911)
# 304       Mikhail Zoshchenko(1895–1958)
#
#                                          Notable works
# 0    The New LifeWooden HorsesTwo Winters and Three...
# 1                                   Novel with Cocaine
# 2    JamilyaThe White ShipThe Day Lasts More Than a...
# 3                                       The Countrymen
# 4    The Scarlet FlowerThe Family ChronicleYears of...
# ..                                                 ...
# 300                           Evenings on the Karpovka
# 301                                The Mushroom-Picker
# 302                               The Tragic Menagerie
# 303                                        Old Shadows
# 304                The GaloshScenes from the Bathhouse
#
# [305 rows x 2 columns]

# %%
novelists['Birthyear'] = novelists['Author'].str.split(')')\
                        .apply(lambda x: x[0])\
                        .str.replace('[^0-9]','').str[:4]

novelists['Author'] = novelists['Author'].str.split('(')\
                        .apply(lambda x:x[0])\
                        .str[:]

# %%
novelists
# Out:
#                       Author  \
# 0             Fyodor Abramov
# 1                  M. Ageyev
# 2          Chinghiz Aitmatov
# 3               David Aizman
# 4             Sergey Aksakov
# ..                       ...
# 300            Maria Zhukova
# 301             Zinovy Zinik
# 302  Lydia Zinovieva-Annibal
# 303     Nikolay Zlatovratsky
# 304       Mikhail Zoshchenko
#
#                                          Notable works Birthyear
# 0    The New LifeWooden HorsesTwo Winters and Three...      1920
# 1                                   Novel with Cocaine      1898
# 2    JamilyaThe White ShipThe Day Lasts More Than a...      1928
# 3                                       The Countrymen      1869
# 4    The Scarlet FlowerThe Family ChronicleYears of...      1791
# ..                                                 ...       ...
# 300                           Evenings on the Karpovka      1804
# 301                                The Mushroom-Picker      1945
# 302                               The Tragic Menagerie      1866
# 303                                        Old Shadows      1845
# 304                The GaloshScenes from the Bathhouse      1895
#
# [305 rows x 3 columns]
